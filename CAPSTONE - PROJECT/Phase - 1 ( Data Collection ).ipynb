# %%
# Data is collected from Kaggle

# In data, I have collected the data Indian Population (2001), (2011), (2020)

# In data, I have collected Area of India

# In data, I have collected Literacy_Rate of India (2001 - 2011), (2015 - 2016), (new)

# In data, I have collected crimes in India (2001 - 2012), (2001 - 2020) and one more crime data

# %%
# link for whole data

# indian population(2011) link   :  https://www.kaggle.com/datasets/danofer/india-census


# indian population(2001) link   :   https://www.kaggle.com/datasets/bazuka/census2001


# indian population(2020) link   :   https://www.kaggle.com/datasets/rahuljangam/indian-population-history-1955-2020


# literacy rate(15 - 16) link    :   https://www.kaggle.com/datasets/rajanand/education-in-india


# literacy rate(01 - 11) link    :     https://www.kaggle.com/datasets/doncorleone92/govt-of-india-literacy-rate


# indian area1 link              :   https://www.kaggle.com/datasets/rushikeshlavate/states-and-union-territories-of-india-by-area


# crime1  link                   :    https://www.kaggle.com/datasets/nehaprabhavalkar/crime-in-india


# crime2(01 - 12)  link          :   https://www.kaggle.com/datasets/khanmohammadanas/district-wise-crimes-in-india


# crime3(01 - 20)  link          :   https://www.kaggle.com/datasets/thedevastator/crime-trends-in-india-from-2001-to-2020

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# importing crime data,  cases registered in Police state-wise in 2016

# %%
crime1 = pd.read_csv("2016_Cases_against_Police_Personnels.csv")

# %%
crime1
# Out:
#     S. No. Category           State/UT  \
# 0        1    State     Andhra Pradesh
# 1        2    State  Arunachal Pradesh
# 2        3    State              Assam
# 3        4    State              Bihar
# 4        5    State       Chhattisgarh
# 5        6    State                Goa
# 6        7    State            Gujarat
# 7        8    State            Haryana
# 8        9    State   Himachal Pradesh
# 9       10    State    Jammu & Kashmir
# 10      11    State          Jharkhand
# 11      12    State          Karnataka
# 12      13    State             Kerala
# 13      14    State     Madhya Pradesh
# 14      15    State        Maharashtra
# 15      16    State            Manipur
# 16      17    State          Meghalaya
# 17      18    State            Mizoram
# 18      19    State           Nagaland
# 19      20    State             Odisha
# 20      21    State             Punjab
# 21      22    State          Rajasthan
# 22      23    State             Sikkim
# ...

# %%
crime1.isna().sum()
# Out:
# S. No.                                                       0
# Category                                                     0
# State/UT                                                     0
# Total Number of Criminal Cases Registered during the year    0
# Police Personnel Arrested                                    0
# Cases Chargesheeted                                          0
# Police Personnel Chargesheeted                               0
# Police Personnel whose Cases were withdrawn/ Disposed Off    0
# Police Personnel whose Trials were Completed                 0
# Police Personnel Convicted                                   0
# Police Personnel Acquitted                                   0
# dtype: int64

# %%
# no nulls are showing in this dataset.

# %%
# importing crime data,   cases registered in Police state-wise in 2017

# %%
crime2 = pd.read_csv("2017_Cases_against_Police_Personnels.csv")
crime2
# Out:
#     S. No.         Category           State/UT  Number of Cases - Registered  \
# 0        1            State     Andhra Pradesh                           164
# 1        2            State  Arunachal Pradesh                             9
# 2        3            State              Assam                             8
# 3        4            State              Bihar                             4
# 4        5            State       Chhattisgarh                            20
# 5        6            State                Goa                            25
# 6        7            State            Gujarat                           191
# 7        8            State            Haryana                            39
# 8        9            State   Himachal Pradesh                             9
# 9       10            State    Jammu & Kashmir                            40
# 10      11            State          Jharkhand                             2
# ...

# %%
crime2.isna().sum()
# Out:
# S. No.                                                      0
# Category                                                    0
# State/UT                                                    0
# Number of Cases - Registered                                0
# Number of Cases - Quashed/Stayed by Courts                  0
# Number of Cases - Chargesheeted                             0
# Number of Cases - Final Report Submitted                    0
# Number of Police Personel - Arrested                        0
# Number of Police Personel - Chargesheeted                   0
# Number of Police Personel - Cases Withdrawn/Disposed Off    0
# Number of Police Personel - Trials were Completed           0
# Number of Police Personel - Convicted                       0
# Number of Police Personel - Acquitted or Discharged         0
# dtype: int64

# %%
# no nulls are showing in dataset.

# %%
# importing crime data,  cases registered in Police state-wise in 2018

# %%
crime3 = pd.read_csv("2018_Cases_against_Police_Personnels.csv")
crime3
# Out:
#     S. No.         Category           State/UT  Number of Cases - Registered  \
# 0        1            State     Andhra Pradesh                            97
# 1        2            State  Arunachal Pradesh                             5
# 2        3            State              Assam                            30
# 3        4            State              Bihar                            17
# 4        5            State       Chhattisgarh                           255
# 5        6            State                Goa                            10
# 6        7            State            Gujarat                           170
# 7        8            State            Haryana                            64
# 8        9            State   Himachal Pradesh                            13
# 9       10            State    Jammu & Kashmir                            47
# 10      11            State          Jharkhand                             2
# ...

# %%
crime3.isna().sum()
# Out:
# S. No.                                                      0
# Category                                                    0
# State/UT                                                    0
# Number of Cases - Registered                                0
# Number of Cases - Quashed/Stayed by Courts                  0
# Number of Cases - Chargesheeted                             0
# Number of Cases - Final Report Submitted                    0
# Number of Police Personel - Arrested                        0
# Number of Police Personel - Chargesheeted                   0
# Number of Police Personel - Cases Withdrawn/Disposed Off    0
# Number of Police Personel - Trials were Completed           0
# Number of Police Personel - Convicted                       0
# Number of Police Personel - Acquitted or Discharged         0
# dtype: int64

# %%
# no nulls are showing in dataset.

# %%
# importing data of persons escaped from police custody of year 2016

# %%
crime_escape1 = pd.read_csv("2016_Escapes_from_Police_Custody.csv")
crime_escape1
# Out:
#     S. No. Category           State/UT  \
# 0        1    State     Andhra Pradesh
# 1        2    State  Arunachal Pradesh
# 2        3    State              Assam
# 3        4    State              Bihar
# 4        5    State       Chhattisgarh
# 5        6    State                Goa
# 6        7    State            Gujarat
# 7        8    State            Haryana
# 8        9    State   Himachal Pradesh
# 9       10    State    Jammu & Kashmir
# 10      11    State          Jharkhand
# 11      12    State          Karnataka
# 12      13    State             Kerala
# 13      14    State     Madhya Pradesh
# 14      15    State        Maharashtra
# 15      16    State            Manipur
# 16      17    State          Meghalaya
# 17      18    State            Mizoram
# 18      19    State           Nagaland
# 19      20    State             Odisha
# 20      21    State             Punjab
# 21      22    State          Rajasthan
# 22      23    State             Sikkim
# ...

# %%
crime_escape1.isna().sum()
# Out:
# S. No.                                                               0
# Category                                                             0
# State/UT                                                             0
# Number of Cases Registered (U/S 224, 225 B)                          0
# Total Number of Persons Escaped from Police Custody                  0
# Persons Escaped from Lockup                                          0
# Persons Escaped Outside the Lockup                                   0
# Escapees Rearrested who Escaped - From Lockup                        0
# Escapees Rearrested who Escaped - Other than Lockup                  0
# Number of Persons Chargedsheeted for Offence of Escape               0
# Disposal by Courts - Trials Completed - Cases Involved               0
# Disposal by Courts - Trials Completed - Number of Persons            0
# Disposal by Courts - Convicted - Cases Involved                      0
# ...

# %%
# no nulls are showing in dataset.

# %%
# importing data of persons escaped from police custody of year 2017

# %%
crime_escape2 = pd.read_csv("2017_Escapes_from_Police_Custody.csv")
crime_escape2
# Out:
#     S. No.         Category           State/UT  Cases Reported  \
# 0        1            State     Andhra Pradesh              36
# 1        2            State  Arunachal Pradesh               3
# 2        3            State              Assam              13
# 3        4            State              Bihar              62
# 4        5            State       Chhattisgarh              27
# 5        6            State                Goa               4
# 6        7            State            Gujarat              41
# 7        8            State            Haryana              25
# 8        9            State   Himachal Pradesh               9
# 9       10            State    Jammu & Kashmir              11
# 10      11            State          Jharkhand               9
# 11      12            State          Karnataka              47
# 12      13            State             Kerala              35
# 13      14            State     Madhya Pradesh             319
# ...

# %%
crime_escape2.isna().sum()
# Out:
# S. No.                                                          0
# Category                                                        0
# State/UT                                                        0
# Cases Reported                                                  0
# Persons Escaped - From lockup                                   0
# Persons Escaped - Outside Lockup                                0
# Persons Escaped - Total                                         0
# Escapees - Re-Arrested                                          0
# Escapees - Absconding                                           0
# Cases against Police for Negligence                             0
# Action taken for Negligence - Police Personnel Arrested         0
# Action taken for Negligence - Police Personnel Chargesheeted    0
# Action taken for Negligence - Police Personnel Convicted        0
# dtype: int64

# %%
# no nulls are showing in the dataset.

# %%
# importing data of persons escaped from police custody of year 2018

# %%
crime_escape3 = pd.read_csv("2018_Escapes_from_Police_Custody.csv")
crime_escape3
# Out:
#     S. No.         Category           State/UT  Cases Reported  \
# 0        1            State     Andhra Pradesh              26
# 1        2            State  Arunachal Pradesh               2
# 2        3            State              Assam              38
# 3        4            State              Bihar              54
# 4        5            State       Chhattisgarh              31
# 5        6            State                Goa               4
# 6        7            State            Gujarat              38
# 7        8            State            Haryana              27
# 8        9            State   Himachal Pradesh              11
# 9       10            State    Jammu & Kashmir              17
# 10      11            State          Jharkhand              13
# 11      12            State          Karnataka              40
# 12      13            State             Kerala              37
# 13      14            State     Madhya Pradesh             312
# ...

# %%
crime_escape3.isna().sum()
# Out:
# S. No.                                                          0
# Category                                                        0
# State/UT                                                        0
# Cases Reported                                                  0
# Persons Escaped - From lockup                                   0
# Persons Escaped - Outside Lockup                                0
# Persons Escaped - Total                                         0
# Escapees - Re-Arrested                                          0
# Escapees - Absconding                                           0
# Cases against Police for Negligence                             0
# Action taken for Negligence - Police Personnel Arrested         0
# Action taken for Negligence - Police Personnel Chargesheeted    0
# Action taken for Negligence - Police Personnel Convicted        0
# dtype: int64

# %%
# no nulls are showing in dataset.

# %%
# importing data for cases registered against rape in 2016

# %%
crime_rape1 = pd.read_csv("2016_Victims_of_Rape.csv")
crime_rape1
# Out:
#     S. No         Category           State/UT  Cases Reported  \
# 0       1            State     Andhra Pradesh             988
# 1       2            State  Arunachal Pradesh              59
# 2       3            State              Assam            1772
# 3       4            State              Bihar             605
# 4       5            State       Chhattisgarh            1908
# 5       6            State                Goa              76
# 6       7            State            Gujarat             477
# 7       8            State            Haryana            1099
# 8       9            State   Himachal Pradesh             249
# 9      10            State    Jammu & Kashmir             296
# 10     11            State          Jharkhand             914
# 11     12            State          Karnataka             546
# 12     13            State             Kerala            2003
# 13     14            State     Madhya Pradesh            5562
# ...

# %%
crime_rape1.isna().sum()
# Out:
# S. No                                                                       0
# Category                                                                    0
# State/UT                                                                    0
# Cases Reported                                                              0
# Child Victims of Rape (Below 18 Yrs) - Below 6 Years                        0
# Child Victims of Rape (Below 18 Yrs) - 6 Years & Above - Below 12 Years     0
# Child Victims of Rape (Below 18 Yrs) - 12 Years & Above - Below 16 Years    0
# Child Victims of Rape (Below 18 Yrs) - 16 Years & Above - Below 18 Years    0
# Child Victims of Rape (Below 18 Yrs) - Total Girl /Child Victims            0
# Women Victims of Rape (Above 18 Yrs) - 18 Years & Above - Below 30 Years    0
# Women Victims of Rape (Above 18 Yrs) - 30 Years & Above - Below 45 Years    0
# Women Victims of Rape (Above 18 Yrs) - 45 Years & Above - Below 60 Years    0
# ...

# %%
# no nulls are showing in dataset.

# %%
# importing data for cases registered against rape in 2017

# %%
crime_rape2 = pd.read_csv("2017_Victims_of_Rape.csv")
crime_rape2
# Out:
#     S. No         Category           State/UT  Cases Reported  \
# 0       1            State     Andhra Pradesh             988
# 1       2            State  Arunachal Pradesh              59
# 2       3            State              Assam            1772
# 3       4            State              Bihar             605
# 4       5            State       Chhattisgarh            1908
# 5       6            State                Goa              76
# 6       7            State            Gujarat             477
# 7       8            State            Haryana            1099
# 8       9            State   Himachal Pradesh             249
# 9      10            State    Jammu & Kashmir             296
# 10     11            State          Jharkhand             914
# 11     12            State          Karnataka             546
# 12     13            State             Kerala            2003
# 13     14            State     Madhya Pradesh            5562
# ...

# %%
crime_rape2.isna().sum()
# Out:
# S. No                                                                       0
# Category                                                                    0
# State/UT                                                                    0
# Cases Reported                                                              0
# Child Victims of Rape (Below 18 Yrs) - Below 6 Years                        0
# Child Victims of Rape (Below 18 Yrs) - 6 Years & Above - Below 12 Years     0
# Child Victims of Rape (Below 18 Yrs) - 12 Years & Above - Below 16 Years    0
# Child Victims of Rape (Below 18 Yrs) - 16 Years & Above - Below 18 Years    0
# Child Victims of Rape (Below 18 Yrs) - Total Girl /Child Victims            0
# Women Victims of Rape (Above 18 Yrs) - 18 Years & Above - Below 30 Years    0
# Women Victims of Rape (Above 18 Yrs) - 30 Years & Above - Below 45 Years    0
# Women Victims of Rape (Above 18 Yrs) - 45 Years & Above - Below 60 Years    0
# ...

# %%
# no nulls are showing in dataset.

# %%
# importing data for cases registered against rape in 2018

# %%
crime_rape3 = pd.read_csv("2018_Victims_of_Rape.csv")
crime_rape3
# Out:
#     S. No         Category          State/UT   Cases Reported  \
# 0       1            State     Andhra Pradesh             971
# 1       2            State  Arunachal Pradesh              67
# 2       3            State              Assam            1648
# 3       4            State              Bihar             651
# 4       5            State       Chhattisgarh            2091
# 5       6            State                Goa              61
# 6       7            State            Gujarat             553
# 7       8            State            Haryana            1296
# 8       9            State   Himachal Pradesh             344
# 9      10            State    Jammu & Kashmir             320
# 10     11            State          Jharkhand            1090
# 11     12            State          Karnataka             492
# 12     13            State             Kerala            1945
# 13     14            State     Madhya Pradesh            5433
# ...

# %%
crime_rape3.isna().sum()
# Out:
# S. No                                                                       0
# Category                                                                    0
# State/UT                                                                    0
# Cases Reported                                                              0
# Child Victims of Rape (Below 18 Yrs) - Below 6 Years                        0
# Child Victims of Rape (Below 18 Yrs) - 6 Years & Above                      0
# Child Victims of Rape (Below 18 Yrs) - 12 Years & Above                     0
# Child Victims of Rape (Below 18 Yrs) - 16 Years & Above                     0
# Child Victims of Rape (Below 18 Yrs) - Total Girl/Child Victims             0
# Women Victims of Rape (Above 18 Yrs) - 18 Years & Above - Below 30 Years    0
# Women Victims of Rape (Above 18 Yrs) - 30 Years & Above - Below 45 Years    0
# Women Victims of Rape (Above 18 Yrs) - 45 Years & Above - Below 60 Years    0
# ...

# %%
# no nulls are showing in dataset.

# %%
# importing area data

# %%
area = pd.read_csv("List_of_states_and_union_territories_of_India_by_area.csv")
area
# Out:
#         Rank          State (S) / Union territory (UT)    Area (km2)  \
# 0     1 (S1)                                 Rajasthan       342,239
# 1     2 (S2)                            Madhya Pradesh       308,252
# 2     3 (S3)                               Maharashtra       307,713
# 3     4 (S4)                             Uttar Pradesh       240,928
# 4     5 (S5)                                   Gujarat       196,024
# 5     6 (S6)                                 Karnataka       191,791
# 6     8 (S7)                            Andhra Pradesh       160,205
# 7     9 (S8)                                    Odisha       155,707
# 8    10 (S9)                              Chhattisgarh       135,191
# 9   11 (S10)                                Tamil Nadu       130,058
# 10  12 (S11)                                 Telangana       112,077
# 11   7 (UT1)                                    Ladakh        96,702
# 12  13 (S12)                                     Bihar        94,163
# ...

# %%
area.isna().sum()
# Out:
# Rank                                      0
# State (S) / Union territory (UT)          0
# Area (km2)                                0
# Region                                    1
# National Share (%)                        0
# Country of comparable size (land mass)    1
# dtype: int64

# %%
# some nulls are showing in dataset

# %%
# filling the null values

# %%
area['Region'] = area['Region'].fillna('Whole')

# %%
area
# Out:
#         Rank          State (S) / Union territory (UT)    Area (km2)  \
# 0     1 (S1)                                 Rajasthan       342,239
# 1     2 (S2)                            Madhya Pradesh       308,252
# 2     3 (S3)                               Maharashtra       307,713
# 3     4 (S4)                             Uttar Pradesh       240,928
# 4     5 (S5)                                   Gujarat       196,024
# 5     6 (S6)                                 Karnataka       191,791
# 6     8 (S7)                            Andhra Pradesh       160,205
# 7     9 (S8)                                    Odisha       155,707
# 8    10 (S9)                              Chhattisgarh       135,191
# 9   11 (S10)                                Tamil Nadu       130,058
# 10  12 (S11)                                 Telangana       112,077
# 11   7 (UT1)                                    Ladakh        96,702
# 12  13 (S12)                                     Bihar        94,163
# ...

# %%
# importing population data of India in 2001

# %%
population_2001 = pd.read_csv('all.csv')
population_2001
# Out:
#      Unnamed: 0   State                                           District  \
# 0             1      AN  District Andamans (01), Andaman & Nicobar Isla...
# 1             2      AN  District Nicobars (02), Andaman & Nicobar Isla...
# 2             3  Andhra        District Adilabad (01), Andhra Pradesh (28)
# 3             4  Andhra       District Nizamabad (02), Andhra Pradesh (28)
# 4             5  Andhra      District Karimnagar (03), Andhra Pradesh (28)
# ..          ...     ...                                                ...
# 585         586      WB           District Puruliya (14), West Bengal (19)
# 586         587      WB                                 District Medinipur
# 587         588      WB                                     District Haora
# 588         589      WB            District Kolkata (17), West Bengal (19)
# 589         590      WB        Twenty Four Parganas (18), West Bengal (19)
#
# ...

# %%
population_2001.isna().sum()
# Out:
# Unnamed: 0               0
# State                    0
# District                 0
# Persons                  0
# Males                    0
#                         ..
# Paved_approach_road     12
# Mud_approach_road       12
# Permanent_House          0
# Semi_permanent_House     0
# Temporary_House          0
# Length: 82, dtype: int64

# %%
# some nulls are showing in the dataset

# %%
# checking individually for all columns nulls values and filling the null values

# %%
population_2001.columns
# Out:
# Index(['Unnamed: 0', 'State', 'District', 'Persons', 'Males', 'Females',
#        'Growth_1991_2001', 'Rural', 'Urban', 'Scheduled_Caste_population',
#        'Percentage_SC_to_total', 'Number_of_households',
#        'Household_size_per_household', 'Sex_ratio_females_per_1000_males',
#        'Sex_ratio_06_years', 'Scheduled_Tribe_population',
#        'Percentage_to_total_population_ST', 'Persons_literate',
#        'Males_Literate', 'Females_Literate', 'Persons_literacy_rate',
#        'Males_Literacy_Rate', 'Females_Literacy_Rate', 'Total_Educated',
#        'Data_without_level', 'Below_Primary', 'Primary', 'Middle',
#        'Matric_Higher_Secondary_Diploma', 'Graduate_and_Above', 'X0_4_years',
#        'X5_14_years', 'X15_59_years', 'X60_years_and_above_Incl_A_N_S',
#        'Total_workers', 'Main_workers', 'Marginal_workers', 'Non_workers',
#        'SC_1_Name', 'SC_1_Population', 'SC_2_Name', 'SC_2_Population',
#        'SC_3_Name', 'SC_3_Population', 'Religeon_1_Name',
# ...

# %%
population_2001['Unnamed: 0'].isna().sum()
# Out:
# 0

# %%
population_2001['State'].isna().sum()
# Out:
# 0

# %%
population_2001['District'].isna().sum()
# Out:
# 0

# %%
population_2001['Persons'].isna().sum()
# Out:
# 0

# %%
population_2001['Males'].isna().sum()
# Out:
# 0

# %%
population_2001['Females'].isna().sum()
# Out:
# 0

# %%
population_2001['Growth_1991_2001'].isna().sum()
# Out:
# 0

# %%
population_2001['Rural'].isna().sum()
# Out:
# 0

# %%
population_2001['Urban'].isna().sum()
# Out:
# 0

# %%
population_2001['Scheduled_Caste_population'].isna().sum()
# Out:
# 563

# %%
population_2001['Scheduled_Caste_population'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Scheduled_Caste_population'].mode()
# Out:
# 0    -
# Name: Scheduled_Caste_population, dtype: object

# %%
population_2001['Scheduled_Caste_population'] = population_2001['Scheduled_Caste_population'].replace('-',1000)

population_2001['Scheduled_Caste_population'] = population_2001['Scheduled_Caste_population'].fillna(1000)

# %%
population_2001['Percentage_SC_to_total'].isna().sum()
# Out:
# 562

# %%
population_2001['Percentage_SC_to_total'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Percentage_SC_to_total'].mode()
# Out:
# 0    -
# Name: Percentage_SC_to_total, dtype: object

# %%
population_2001['Percentage_SC_to_total'] = population_2001['Percentage_SC_to_total'].replace('-',0)

population_2001['Percentage_SC_to_total'] = population_2001['Percentage_SC_to_total'].fillna(0)

# %%
population_2001['Percentage_SC_to_total'].isna().sum()
# Out:
# 0

# %%
population_2001['Number_of_households'].isna().sum()
# Out:
# 0

# %%
population_2001['Household_size_per_household'].isna().sum()
# Out:
# 0

# %%
population_2001['Sex_ratio_females_per_1000_males'].isna().sum()
# Out:
# 0

# %%
population_2001['Sex_ratio_06_years'].isna().sum()
# Out:
# 0

# %%
population_2001['Scheduled_Tribe_population'].isna().sum()
# Out:
# 0

# %%
population_2001['Percentage_to_total_population_ST'].isna().sum()
# Out:
# 4

# %%
population_2001['Percentage_to_total_population_ST'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Percentage_to_total_population_ST'].mode()
# Out:
# 0    -
# Name: Percentage_to_total_population_ST, dtype: object

# %%
population_2001['Percentage_to_total_population_ST'] = population_2001['Percentage_to_total_population_ST'].replace('-',20)

population_2001['Percentage_to_total_population_ST'] = population_2001['Percentage_to_total_population_ST'].fillna(30)

# %%
population_2001['Percentage_to_total_population_ST'].isna().sum()
# Out:
# 0

# %%
population_2001['Persons_literate'].isna().sum()
# Out:
# 0

# %%
population_2001['Males_Literate'].isna().sum()
# Out:
# 0

# %%
population_2001['Females_Literate'].isna().sum()
# Out:
# 0

# %%
population_2001['Persons_literacy_rate'].isna().sum()
# Out:
# 0

# %%
population_2001['Males_Literacy_Rate'].isna().sum()
# Out:
# 0

# %%
population_2001['Females_Literacy_Rate'].isna().sum()
# Out:
# 0

# %%
population_2001['Total_Educated'].isna().sum()
# Out:
# 3

# %%
population_2001['Total_Educated'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Total_Educated'].mean()
# Out:
# 944478.2095400341

# %%
population_2001['Total_Educated'] = population_2001['Total_Educated'].fillna(940000)

# %%
population_2001['Data_without_level'].isna().sum()
# Out:
# 3

# %%
population_2001['Data_without_level'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Data_without_level'].mean()
# Out:
# 33894.31686541738

# %%
population_2001['Data_without_level'] = population_2001['Data_without_level'].fillna(34000)

# %%
population_2001['Below_Primary'].isna().sum()
# Out:
# 3

# %%
population_2001['Below_Primary'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Below_Primary'].mean()
# Out:
# 243767.33049403748

# %%
population_2001['Below_Primary'] = population_2001['Below_Primary'].fillna(240000)

# %%
population_2001['Primary'].isna().sum()
# Out:
# 3

# %%
population_2001['Primary'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Primary'].mean()
# Out:
# 246427.64735945486

# %%
population_2001['Primary'] = population_2001['Primary'].fillna(250000)

# %%
population_2001['Middle'].isna().sum()
# Out:
# 3

# %%
population_2001['Middle'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Middle'].mean()
# Out:
# 152429.41056218056

# %%
population_2001['Middle'] = population_2001['Middle'].fillna(152000)

# %%
population_2001['Matric_Higher_Secondary_Diploma'].isna().sum()
# Out:
# 3

# %%
population_2001['Matric_Higher_Secondary_Diploma'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Matric_Higher_Secondary_Diploma'].mean()
# Out:
# 204171.03066439522

# %%
population_2001['Matric_Higher_Secondary_Diploma'] = population_2001['Matric_Higher_Secondary_Diploma'].fillna(200000)

# %%
population_2001['Graduate_and_Above'].isna().sum()
# Out:
# 3

# %%
population_2001['Graduate_and_Above'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Graduate_and_Above'].mean()
# Out:
# 63622.16695059625

# %%
population_2001['Graduate_and_Above'] = population_2001['Graduate_and_Above'].fillna(65000)

# %%
population_2001['X0_4_years'].isna().sum()
# Out:
# 3

# %%
population_2001['X0_4_years'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['X0_4_years'].mean()
# Out:
# 186595.36967632026

# %%
population_2001['X0_4_years'] = population_2001['X0_4_years'].fillna(185000)

# %%
population_2001['X5_14_years'].isna().sum()
# Out:
# 3

# %%
population_2001['X5_14_years'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['X5_14_years'].mean()
# Out:
# 427263.4190800681

# %%
population_2001['X5_14_years'] = population_2001['X5_14_years'].fillna(420000)

# %%
population_2001['X15_59_years'].isna().sum()
# Out:
# 3

# %%
population_2001['X15_59_years'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['X15_59_years'].mean()
# Out:
# 986585.9540034072

# %%
population_2001['X15_59_years'] = population_2001['X15_59_years'].fillna(980000)

# %%
population_2001['X60_years_and_above_Incl_A_N_S'].isna().sum()
# Out:
# 3

# %%
population_2001['X60_years_and_above_Incl_A_N_S'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['X60_years_and_above_Incl_A_N_S'].mean()
# Out:
# 133762.27427597955

# %%
population_2001['X60_years_and_above_Incl_A_N_S'] = population_2001['X60_years_and_above_Incl_A_N_S'].fillna(1337750)

# %%
population_2001['Total_workers'].isna().sum()
# Out:
# 0

# %%
population_2001['Main_workers'].isna().sum()
# Out:
# 0

# %%
population_2001['Marginal_workers'].isna().sum()
# Out:
# 0

# %%
population_2001['Non_workers'].isna().sum()
# Out:
# 0

# %%
population_2001['SC_1_Name'].isna().sum()
# Out:
# 53

# %%
population_2001['SC_1_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['SC_1_Name'].mode()
# Out:
# 0    1.Chamar etc.
# Name: SC_1_Name, dtype: object

# %%
population_2001['SC_1_Name'] = population_2001['SC_1_Name'].fillna('1.Chamar etc.')

# %%
population_2001['SC_1_Population'].isna().sum()
# Out:
# 13

# %%
population_2001['SC_1_Population'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['SC_1_Population'].mean()
# Out:
# 152126.13691507798

# %%
population_2001['SC_1_Population'] = population_2001['SC_1_Population'].fillna(152000)

# %%
population_2001['SC_2_Name'].isna().sum()
# Out:
# 64

# %%
population_2001['SC_2_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['SC_2_Name'].mode()
# Out:
# 0    2.Chamar etc.
# Name: SC_2_Name, dtype: object

# %%
population_2001['SC_2_Name'] = population_2001['SC_2_Name'].fillna('2.Chamar etc.')

# %%
population_2001['SC_2_Population'].isna().sum()
# Out:
# 13

# %%
population_2001['SC_2_Population'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['SC_2_Population'].mean()
# Out:
# 57613.90121317158

# %%
population_2001['SC_2_Population'] = population_2001['SC_2_Population'].fillna(57500)

# %%
population_2001['SC_3_Name'].isna().sum()
# Out:
# 66

# %%
population_2001['SC_3_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['SC_3_Name'].mode()
# Out:
# 0    3.Chamar etc.
# 1          3.Dhobi
# Name: SC_3_Name, dtype: object

# %%
population_2001['SC_3_Name'] = population_2001['SC_3_Name'].fillna('3.Chamar etc.')

# %%
population_2001['SC_3_Population'].isna().sum()
# Out:
# 13

# %%
population_2001['SC_3_Population'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['SC_3_Population'].mean()
# Out:
# 26567.043327556326

# %%
population_2001['SC_3_Population'] = population_2001['SC_3_Population'].fillna(26500)

# %%
population_2001['Religeon_1_Name'].isna().sum()
# Out:
# 53

# %%
population_2001['Religeon_1_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Religeon_1_Name'].mode()
# Out:
# 0    1.Hindus
# Name: Religeon_1_Name, dtype: object

# %%
population_2001['Religeon_1_Name'] = population_2001['Religeon_1_Name'].fillna('1.Hindus')

# %%
population_2001['Religeon_1_Population'].isna().sum()
# Out:
# 0

# %%
population_2001['Religeon_2_Name'].isna().sum()
# Out:
# 53

# %%
population_2001['Religeon_2_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Religeon_2_Name'].mode()
# Out:
# 0    2.Muslims
# Name: Religeon_2_Name, dtype: object

# %%
population_2001['Religeon_2_Name'] = population_2001['Religeon_2_Name'].fillna('2.Muslims')

# %%
population_2001['Religeon_2_Population'].isna().sum()
# Out:
# 0

# %%
population_2001['Religeon_3_Name'].isna().sum()
# Out:
# 53

# %%
population_2001['Religeon_3_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Religeon_3_Name'].mode()
# Out:
# 0    3.Christians
# Name: Religeon_3_Name, dtype: object

# %%
population_2001['Religeon_3_Name'] = population_2001['Religeon_3_Name'].fillna('3.Christians')

# %%
population_2001['Religeon_3_Population'].isna().sum()
# Out:
# 0

# %%
population_2001['ST_1_Name'].isna().sum()
# Out:
# 0

# %%
population_2001['ST_1_Population'].isna().sum()
# Out:
# 51

# %%
population_2001['ST_1_Population'].dtypes
# Out:
# dtype('O')

# %%
population_2001['ST_1_Population'].mode()
# Out:
# 0    243
# Name: ST_1_Population, dtype: object

# %%
population_2001['ST_1_Population'] = population_2001['ST_1_Population'].fillna(243)

# %%
population_2001['ST_2_Name'].isna().sum()
# Out:
# 50

# %%
population_2001['ST_2_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['ST_2_Name'].mode()
# Out:
# 0    2.Generic Tribes etc.
# Name: ST_2_Name, dtype: object

# %%
population_2001['ST_2_Name'] = population_2001['ST_2_Name'].fillna('2.Generic Tribes etc.')

# %%
population_2001['ST_2_Population'].isna().sum()
# Out:
# 53

# %%
population_2001['ST_2_Population'].dtypes
# Out:
# dtype('O')

# %%
population_2001['ST_2_Population'].mode()
# Out:
# 0    85
# Name: ST_2_Population, dtype: object

# %%
population_2001['ST_2_Population'] = population_2001['ST_2_Population'].fillna(85)

# %%
population_2001['ST_3_Name'].isna().sum()
# Out:
# 50

# %%
population_2001['ST_3_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['ST_3_Name'].mode()
# Out:
# 0    3.Generic Tribes etc.
# Name: ST_3_Name, dtype: object

# %%
population_2001['ST_3_Name'] = population_2001['ST_3_Name'].fillna('3.Generic Tribes etc.')

# %%
population_2001['ST_3_Population'].isna().sum()
# Out:
# 52

# %%
population_2001['ST_3_Population'].dtypes
# Out:
# dtype('O')

# %%
population_2001['ST_3_Population'].mode()
# Out:
# 0    1
# Name: ST_3_Population, dtype: object

# %%
population_2001['ST_3_Population'] = population_2001['ST_3_Population'].fillna(1)

# %%
population_2001['Imp_Town_1_Name'].isna().sum()
# Out:
# 21

# %%
population_2001['Imp_Town_1_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Imp_Town_1_Name'].mode()
# Out:
# 0    (MB)
# Name: Imp_Town_1_Name, dtype: object

# %%
population_2001['Imp_Town_1_Name'] = population_2001['Imp_Town_1_Name'].fillna('MB')

# %%
population_2001['Imp_Town_1_Population'].isna().sum()
# Out:
# 14

# %%
population_2001['Imp_Town_1_Population'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Imp_Town_1_Population'].mean()
# Out:
# 248160.41145833334

# %%
population_2001['Imp_Town_1_Population'] = population_2001['Imp_Town_1_Population'].fillna(240000)

# %%
population_2001['Imp_Town_2_Name'].isna().sum()
# Out:
# 97

# %%
population_2001['Imp_Town_2_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Imp_Town_2_Name'].mode()
# Out:
# 0              (M)
# 1    2.DMC(U) Part
# Name: Imp_Town_2_Name, dtype: object

# %%
population_2001['Imp_Town_2_Name'] = population_2001['Imp_Town_2_Name'].fillna('M')

# %%
population_2001['Imp_Town_2_Population'].isna().sum()
# Out:
# 64

# %%
population_2001['Imp_Town_2_Population'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Imp_Town_2_Population'].mean()
# Out:
# 68726.90114068441

# %%
population_2001['Imp_Town_2_Population'] = population_2001['Imp_Town_2_Population'].fillna(65000)

# %%
population_2001['Imp_Town_3_Name'].isna().sum()
# Out:
# 142

# %%
population_2001['Imp_Town_3_Name'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Imp_Town_3_Name'].mode()
# Out:
# 0    (M)
# Name: Imp_Town_3_Name, dtype: object

# %%
population_2001['Imp_Town_3_Name'] = population_2001['Imp_Town_3_Name'].fillna('M')

# %%
population_2001['Imp_Town_3_Population'].isna().sum()
# Out:
# 108

# %%
population_2001['Imp_Town_3_Population'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Imp_Town_3_Population'].mean()
# Out:
# 41223.5622406639

# %%
population_2001['Imp_Town_3_Population'] = population_2001['Imp_Town_3_Population'].fillna(40000)

# %%
population_2001['Total_Inhabited_Villages'].isna().sum()
# Out:
# 12

# %%
population_2001['Total_Inhabited_Villages'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Total_Inhabited_Villages'].mean()
# Out:
# 1016.4515570934255

# %%
population_2001['Total_Inhabited_Villages'] = population_2001['Total_Inhabited_Villages'].fillna(1110)

# %%
population_2001['Drinking_water_facilities'].isna().sum()
# Out:
# 12

# %%
population_2001['Drinking_water_facilities'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Drinking_water_facilities'].mean()
# Out:
# 1009.6712802768166

# %%
population_2001['Drinking_water_facilities'].isna().sum()
# Out:
# 12

# %%
population_2001['Drinking_water_facilities'] = population_2001['Drinking_water_facilities'].fillna(1110)

# %%
population_2001['Safe_Drinking_water'].isna().sum()
# Out:
# 12

# %%
population_2001['Safe_Drinking_water'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Safe_Drinking_water'].mean()
# Out:
# 992.0449826989619

# %%
population_2001['Safe_Drinking_water'] = population_2001['Safe_Drinking_water'].fillna(950)

# %%
population_2001['Electricity_Power_Supply'].isna().sum()
# Out:
# 12

# %%
population_2001['Electricity_Power_Supply'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Electricity_Power_Supply'].mean()
# Out:
# 774.7595155709342

# %%
population_2001['Electricity_Power_Supply'] = population_2001['Electricity_Power_Supply'].fillna(750)

# %%
population_2001['Electricity_domestic'].isna().sum()
# Out:
# 12

# %%
population_2001['Electricity_domestic'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Electricity_domestic'].mode()
# Out:
# 0    -
# Name: Electricity_domestic, dtype: object

# %%
population_2001['Electricity_domestic'] = population_2001['Electricity_domestic'].replace('-',250)

population_2001['Electricity_domestic'] = population_2001['Electricity_domestic'].fillna(300)

# %%
population_2001['Electricity_domestic'].isna().sum()
# Out:
# 0

# %%
population_2001['Electricity_Agriculture'].isna().sum()
# Out:
# 208

# %%
population_2001['Electricity_Agriculture'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Electricity_Agriculture'].mode()
# Out:
# 0    -
# Name: Electricity_Agriculture, dtype: object

# %%
population_2001['Electricity_Agriculture'] = population_2001['Electricity_Agriculture'].replace('-',100)

population_2001['Electricity_Agriculture'] = population_2001['Electricity_Agriculture'].fillna(100)

# %%
population_2001['Electricity_Agriculture'].isna().sum()
# Out:
# 0

# %%
population_2001['Primary_school'].isna().sum()
# Out:
# 12

# %%
population_2001['Primary_school'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Primary_school'].mean()
# Out:
# 796.7941176470588

# %%
population_2001['Primary_school'] = population_2001['Primary_school'].fillna(750)

# %%
population_2001['Middle_schools'].isna().sum()
# Out:
# 12

# %%
population_2001['Middle_schools'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Middle_schools'].mode()
# Out:
# 0    -
# Name: Middle_schools, dtype: object

# %%
population_2001['Middle_schools'] = population_2001['Middle_schools'].replace('-',150)

population_2001['Middle_schools'] = population_2001['Middle_schools'].fillna(155)

# %%
population_2001['Middle_schools'].isna().sum()
# Out:
# 0

# %%
population_2001['Secondary_Sr_Secondary_schools'].isna().sum()
# Out:
# 12

# %%
population_2001['Secondary_Sr_Secondary_schools'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Secondary_Sr_Secondary_schools'].mode()
# Out:
# 0    105
# 1     42
# 2     68
# Name: Secondary_Sr_Secondary_schools, dtype: object

# %%
population_2001['Secondary_Sr_Secondary_schools'] = population_2001['Secondary_Sr_Secondary_schools'].fillna(105)

# %%
population_2001['College'].isna().sum()
# Out:
# 52

# %%
population_2001['College'].dtypes
# Out:
# dtype('O')

# %%
population_2001['College'].mode()
# Out:
# 0    -
# Name: College, dtype: object

# %%
population_2001['College'] = population_2001['College'].replace('-',10)

# %%
population_2001['College'] = population_2001['College'].fillna(10)

# %%
population_2001['College'].isna().sum()
# Out:
# 0

# %%
population_2001['Medical_facility'].isna().sum()
# Out:
# 12

# %%
population_2001['Medical_facility'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Medical_facility'].mode()
# Out:
# 0    118
# 1    197
# 2    229
# 3    279
# 4    375
# 5     48
# 6     67
# 7     74
# Name: Medical_facility, dtype: object

# %%
population_2001['Medical_facility'] = population_2001['Medical_facility'].fillna(118)

# %%
population_2001['Primary_Health_Centre'].isna().sum()
# Out:
# 12

# %%
population_2001['Primary_Health_Centre'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Primary_Health_Centre'].mode()
# Out:
# 0    16
# 1    18
# 2    20
# Name: Primary_Health_Centre, dtype: object

# %%
population_2001['Primary_Health_Centre'] = population_2001['Primary_Health_Centre'].fillna(16)

# %%
population_2001['Primary_Health_Sub_Centre'].isna().sum()
# Out:
# 12

# %%
population_2001['Primary_Health_Sub_Centre'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Primary_Health_Sub_Centre'].mode()
# Out:
# 0    28
# Name: Primary_Health_Sub_Centre, dtype: object

# %%
population_2001['Primary_Health_Sub_Centre'] = population_2001['Primary_Health_Sub_Centre'].fillna(28)

# %%
population_2001['Post_telegram_and_telephone_facility'].isna().sum()
# Out:
# 12

# %%
population_2001['Post_telegram_and_telephone_facility'].dtypes
# Out:
# dtype('float64')

# %%
population_2001['Post_telegram_and_telephone_facility'].mean()
# Out:
# 419.7266435986159

# %%
population_2001['Post_telegram_and_telephone_facility'] = population_2001['Post_telegram_and_telephone_facility'].fillna(410)

# %%
population_2001['Bus_services'].isna().sum()
# Out:
# 12

# %%
population_2001['Bus_services'].dtypes
# Out:
# dtype('O')

# %%
population_2001['Bus_services'].mode()
# Out:
# 0    146
# Name: Bus_services, dtype: object

# %%
population_2001['Bus_services'] = population_2001['Bus_services'].fillna(146)

# %%
population_2001['Paved_approach_road'].isna().sum()
# Out:
# 12

# %%
population_2001['Paved_approach_road'] = population_2001['Paved_approach_road'].fillna(100)

# %%
population_2001['Mud_approach_road'].isna().sum()
# Out:
# 12

# %%
population_2001['Mud_approach_road'] = population_2001['Mud_approach_road'].fillna(197)

# %%
population_2001['Permanent_House'].isna().sum()
# Out:
# 0

# %%
population_2001['Semi_permanent_House'].isna().sum()
# Out:
# 0

# %%
population_2001['Temporary_House'].isna().sum()
# Out:
# 0

# %%
# all null values have filled up.

# %%
# importing population data for India in 2011

# %%
population_2011 = pd.read_csv("india_districts_census_2011.csv")
population_2011
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
population_2011.isna().sum()
# Out:
# District code                    0
# State name                       0
# District name                    0
# Population                       0
# Male                             0
#                                 ..
# Power_Parity_Rs_330000_425000    0
# Power_Parity_Rs_425000_545000    0
# Power_Parity_Rs_330000_545000    0
# Power_Parity_Above_Rs_545000     0
# Total_Power_Parity               0
# Length: 118, dtype: int64

# %%
# no nulls are showing in dataset.

# %%
# importing population data for India in 2011

# %%
population_2020 = pd.read_csv("Historical_data_Population.csv")
population_2020
# Out:
#     Unnamed: 0  Year  Population Yearly % Change  Yearly Change  \
# 0            0  2020  1380004385          0.99 %       13586631
# 1            1  2019  1366417754          1.02 %       13775474
# 2            2  2018  1352642280          1.04 %       13965495
# 3            3  2017  1338676785          1.07 %       14159536
# 4            4  2016  1324517249          1.10 %       14364846
# 5            5  2015  1310152403          1.20 %       15174247
# 6            6  2010  1234281170          1.47 %       17334249
# 7            7  2005  1147609927          1.67 %       18206876
# 8            8  2000  1056575549          1.85 %       18530592
# 9            9  1995   963922588          1.99 %       18128958
# 10          10  1990   873277798          2.17 %       17783558
# 11          11  1985   784360008          2.33 %       17081433
# 12          12  1980   698952844          2.32 %       15169989
# 13          13  1975   623102897          2.33 %       13582621
# ...

# %%
population_2020.isna().sum()
# Out:
# Unnamed: 0                      0
# Year                            0
# Population                      0
# Yearly % Change                 0
# Yearly Change                   0
# Migrants (net)                  0
# Median Age                      0
# Fertility Rate                  0
# Density (P/Km²)                 0
# Urban Pop %                     0
# Urban Population                0
# Country's Share of World Pop    0
# World Population                0
# IndiaGlobal Rank                0
# dtype: int64

# %%
# no null values are showing in dataset

# %%
# importing literacy rate data

# %%
literacy1 = pd.read_csv('GOI.csv')
literacy1
# Out:
#            Category Country/ States/ Union Territories Name  \
# 0           Country                                   INDIA
# 1             State                          Andhra Pradesh
# 2             State                       Arunachal Pradesh
# 3             State                                   Assam
# 4             State                                   Bihar
# 5             State                            Chhattisgarh
# 6             State                                     Goa
# 7             State                                 Gujarat
# 8             State                                 Haryana
# 9             State                        Himachal Pradesh
# 10            State                         Jammu & Kashmir
# 11            State                               Jharkhand
# 12            State                               Karnataka
# 13            State                                  Kerala
# 14            State                          Madhya Pradesh
# ...

# %%
literacy1.isna().sum()
# Out:
# Category                                   0
# Country/ States/ Union Territories Name    0
# Literacy Rate (Persons) - Total - 2001     0
# Literacy Rate (Persons) - Total - 2011     0
# Literacy Rate (Persons) - Rural - 2001     0
# Literacy Rate (Persons) - Rural - 2011     0
# Literacy Rate (Persons) - Urban - 2001     0
# Literacy Rate (Persons) - Urban - 2011     0
# dtype: int64

# %%
# no null values are showing in dataset

# %%
# importing literacy rate data of 2015-2016

# %%
literacy2 = pd.read_csv("2015_16_Districtwise.csv")
literacy2
# Out:
#      AC_YEAR  STATCD  DISTCD         STATNAME     DISTNAME  DISTRICTS  BLOCKS  \
# 0    2015-16       1     101  JAMMU & KASHMIR      KUPWARA          1      13
# 1    2015-16       1     102  JAMMU & KASHMIR     BARAMULA          1      18
# 2    2015-16       1     103  JAMMU & KASHMIR     SRINAGAR          1       8
# 3    2015-16       1     104  JAMMU & KASHMIR       BADGAM          1      13
# 4    2015-16       1     105  JAMMU & KASHMIR      PULWAMA          1       8
# ..       ...     ...     ...              ...          ...        ...     ...
# 675  2015-16      36    3606        TELANGANA  RANGA REDDY          1      37
# 676  2015-16      36    3607        TELANGANA  MAHBUBNAGAR          1      64
# 677  2015-16      36    3608        TELANGANA     NALGONDA          1      59
# 678  2015-16      36    3609        TELANGANA     WARANGAL          1      51
# 679  2015-16      36    3610        TELANGANA      KHAMMAM          1      41
#
# ...

# %%
literacy2.isna().sum()
# Out:
# AC_YEAR     0
# STATCD      0
# DISTCD      0
# STATNAME    0
# DISTNAME    0
#            ..
# TOTCLS3G    0
# TOTCLS4G    0
# TOTCLS5G    0
# TOTCLS6G    0
# TOTCLS7G    0
# Length: 819, dtype: int64

# %%
# no null values are showing in dataset

# %%
# importing literacy rate data

# %%
literacy3 = pd.read_csv("List_of_Indian_states_and_union_territories_by_literacy_rate.csv")
literacy3
# Out:
#     Unnamed: 0                 State or UT Census 2011[4] Census 2011[4].1  \
# 0          NaN                 State or UT        Average             Male
# 1          0.0                       India          74.04            82.14
# 2          1.0             A&N islands[UT]          86.27            90.11
# 3          2.0           Andhra Pradesh[a]           66.4            75.56
# 4          3.0           Arunachal Pradesh          66.95            73.69
# 5          4.0                       Assam          73.18            78.81
# 6          5.0                       Bihar          69.82            73.39
# 7          6.0                Chhattisgarh          71.04            81.45
# 8          7.0              Chandigarh[UT]          86.43            90.54
# 9          8.0  Dadra and Nagar Haveli[UT]          77.65            86.46
# 10         9.0             Daman & Diu[UT]          87.07            91.48
# ...

# %%
literacy3.isna().sum()
# Out:
# Unnamed: 0                1
# State or UT               0
# Census 2011[4]            0
# Census 2011[4].1          0
# Census 2011[4].2          0
# NSO survey (2017)[5]      0
# NSO survey (2017)[5].1    0
# NSO survey (2017)[5].2    0
# dtype: int64

# %%
# one null is showing in nominal column (Unnamed: 0).
