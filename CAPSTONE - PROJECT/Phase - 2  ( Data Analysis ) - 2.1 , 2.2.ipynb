# %%
# importing libraries for reading the dataset

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# importing libraries for visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2.1 Analysis of Literacy rate vs Total crimes.

# %%
crime1 = pd.read_csv("2016_Cases_against_Police_Personnels.csv")
crime1
# Out:
#     S. No. Category           State/UT  \
# 0        1    State     Andhra Pradesh
# 1        2    State  Arunachal Pradesh
# 2        3    State              Assam
# 3        4    State              Bihar
# 4        5    State       Chhattisgarh
# 5        6    State                Goa
# 6        7    State            Gujarat
# 7        8    State            Haryana
# 8        9    State   Himachal Pradesh
# 9       10    State    Jammu & Kashmir
# 10      11    State          Jharkhand
# 11      12    State          Karnataka
# 12      13    State             Kerala
# 13      14    State     Madhya Pradesh
# 14      15    State        Maharashtra
# 15      16    State            Manipur
# 16      17    State          Meghalaya
# 17      18    State            Mizoram
# 18      19    State           Nagaland
# 19      20    State             Odisha
# 20      21    State             Punjab
# 21      22    State          Rajasthan
# 22      23    State             Sikkim
# ...

# %%
#  importing literacy data

# %%
literacy1 = pd.read_csv('GOI.csv')
literacy1
# Out:
#            Category Country/ States/ Union Territories Name  \
# 0           Country                                   INDIA
# 1             State                          Andhra Pradesh
# 2             State                       Arunachal Pradesh
# 3             State                                   Assam
# 4             State                                   Bihar
# 5             State                            Chhattisgarh
# 6             State                                     Goa
# 7             State                                 Gujarat
# 8             State                                 Haryana
# 9             State                        Himachal Pradesh
# 10            State                         Jammu & Kashmir
# 11            State                               Jharkhand
# 12            State                               Karnataka
# 13            State                                  Kerala
# 14            State                          Madhya Pradesh
# ...

# %%
# extracting useable columns from above data and assigning to new variable

# %%
a = crime1['State/UT']

b = crime1['Total Number of Criminal Cases Registered during the year']

c = literacy1['Literacy Rate (Persons) - Total - 2001']

# %%
c = c[1:]
c
# Out:
# 1     60.5
# 2     54.3
# 3     63.3
# 4     47.0
# 5     64.7
# 6     82.0
# 7     69.1
# 8     67.9
# 9     76.5
# 10    55.5
# 11    53.6
# 12    66.6
# 13    90.9
# 14    63.7
# 15    76.9
# 16    70.5
# 17    62.6
# 18    88.8
# 19    66.6
# 20    63.1
# 21    69.7
# 22    60.4
# 23    68.8
# 24    73.5
# 25    73.2
# 26    56.3
# 27    71.6
# 28    68.6
# 29    81.3
# 30    81.9
# 31    57.6
# 32    78.2
# 33    86.7
# 34    81.7
# 35    81.2
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
# creating new dataframe

# %%
crime_vs_literacy = pd.DataFrame({'State/UT':a,'Crimes':b,'Literacy_Rate':c})

# %%
crime_vs_literacy
# Out:
#              State/UT  Crimes  Literacy_Rate
# 0      Andhra Pradesh     100            NaN
# 1   Arunachal Pradesh      24           60.5
# 2               Assam      37           54.3
# 3               Bihar      43           63.3
# 4        Chhattisgarh      65           47.0
# 5                 Goa      20           64.7
# 6             Gujarat     130           82.0
# 7             Haryana      34           69.1
# 8    Himachal Pradesh      11           67.9
# 9     Jammu & Kashmir      29           76.5
# 10          Jharkhand       3           55.5
# 11          Karnataka      63           53.6
# 12             Kerala     171           66.6
# 13     Madhya Pradesh      66           90.9
# 14        Maharashtra     487           63.7
# 15            Manipur       0           76.9
# 16          Meghalaya     265           70.5
# 17            Mizoram       0           62.6
# 18           Nagaland      12           88.8
# 19             Odisha      64           66.6
# ...

# %%
# a null is showing and filling it

# %%
crime_vs_literacy = crime_vs_literacy.fillna(60.5)

# %%
crime_vs_literacy
# Out:
#              State/UT  Crimes  Literacy_Rate
# 0      Andhra Pradesh     100           60.5
# 1   Arunachal Pradesh      24           60.5
# 2               Assam      37           54.3
# 3               Bihar      43           63.3
# 4        Chhattisgarh      65           47.0
# 5                 Goa      20           64.7
# 6             Gujarat     130           82.0
# 7             Haryana      34           69.1
# 8    Himachal Pradesh      11           67.9
# 9     Jammu & Kashmir      29           76.5
# 10          Jharkhand       3           55.5
# 11          Karnataka      63           53.6
# 12             Kerala     171           66.6
# 13     Madhya Pradesh      66           90.9
# 14        Maharashtra     487           63.7
# 15            Manipur       0           76.9
# 16          Meghalaya     265           70.5
# 17            Mizoram       0           62.6
# 18           Nagaland      12           88.8
# 19             Odisha      64           66.6
# ...

# %%
# spliting data into two variables

# %%
x = crime_vs_literacy['Crimes']

y = crime_vs_literacy['Literacy_Rate']

# %%
# individual scatter plot for crime and literacy for all states

# %%
# scatter plot for Andhra Pradesh data

# %%
plt.figure()

plt.scatter(x[0:1],y[0:1])

plt.xlabel('Andhra Crime')
plt.ylabel('Andhra Literacy')

plt.show()

# %%
# scatter plot for Arunachal Pradesh data

# %%
plt.figure()

plt.scatter(x[1:2],y[1:2])

plt.xlabel('Arunachal Crime')
plt.ylabel('Arunachal Literacy')

plt.show()

# %%
# scatter plot for Assam data

# %%
plt.figure()

plt.scatter(x[2:3],y[2:3])

plt.xlabel('Assam Crime')
plt.ylabel('Assam Literacy')

plt.show()

# %%
# scatter plot for Bihar data

# %%
plt.figure()

plt.scatter(x[3:4],y[3:4])

plt.xlabel('Bihar Crime')
plt.ylabel('Bihar Literacy')

plt.show()

# %%
# scatter plot for Chattisgarh data

# %%
plt.figure()

plt.scatter(x[4:5],y[4:5])

plt.xlabel('Chattisgarh Crime')
plt.ylabel('Chattisgarh Literacy')

plt.show()

# %%
# scatter plot for Goa data

# %%
plt.figure()

plt.scatter(x[5:6],y[5:6])

plt.xlabel('Goa Crime')
plt.ylabel('Goa Literacy')

plt.show()

# %%
# scatter plot for Gujarat data

# %%
plt.figure()

plt.scatter(x[6:7],y[6:7])

plt.xlabel('Gujarat Crime')
plt.ylabel('Gujarat Literacy')

plt.show()

# %%
# scatter plot for Haryana data

# %%
plt.figure()

plt.scatter(x[7:8],y[7:8])

plt.xlabel('Haryana Crime')
plt.ylabel('Haryana Literacy')

plt.show()

# %%
# scatter plot for Himachal Pradesh data

# %%
plt.figure()

plt.scatter(x[8:9],y[8:9])

plt.xlabel('Himachal Pradesh Crime')
plt.ylabel('Himachal Pradesh Literacy')

plt.show()

# %%
# scatter plot for Jammu & Kashmir data

# %%
plt.figure()

plt.scatter(x[9:10],y[9:10])

plt.xlabel('Jammu & Kashmir Crime')
plt.ylabel('Jammu & Kashmir Literacy')

plt.show()

# %%
# scatter plot for Jharkhand data

# %%
plt.figure()

plt.scatter(x[10:11],y[10:11])

plt.xlabel('Jharkhand Crime')
plt.ylabel('Jharkhand Literacy')

plt.show()

# %%
# scatter plot for Karnataka data

# %%
plt.figure()

plt.scatter(x[11:12],y[11:12])

plt.xlabel('Karnataka Crime')
plt.ylabel('Karnataka Literacy')

plt.show()

# %%
# scatter plot for Kerala data

# %%
plt.figure()

plt.scatter(x[12:13],y[12:13])

plt.xlabel('Kerala Crime')
plt.ylabel('Kerala Literacy')

plt.show()

# %%
# scatter plot for Madhya Pradesh data

# %%
plt.figure()

plt.scatter(x[13:14],y[13:14])

plt.xlabel('Madhya Pradesh Crime')
plt.ylabel('Madhya Pradesh Literacy')

plt.show()

# %%
# scatter plot for Maharasthra data

# %%
plt.figure()

plt.scatter(x[14:15],y[14:15])

plt.xlabel('Maharashtra Crime')
plt.ylabel('Maharashtra Literacy')

plt.show()

# %%
# scatter plot for Manipur data

# %%
plt.figure()

plt.scatter(x[15:16],y[15:16])

plt.xlabel('Manipur Crime')
plt.ylabel('Manipur Literacy')

plt.show()

# %%
# scatter plot for Meghalaya data

# %%
plt.figure()

plt.scatter(x[16:17],y[16:17])

plt.xlabel('Meghalaya Crime')
plt.ylabel('Meghalaya Literacy')

plt.show()

# %%
# scatter plot for Mizoram data

# %%
plt.figure()

plt.scatter(x[17:18],y[17:18])

plt.xlabel('Mizoram Crime')
plt.ylabel('Mizoram Literacy')

plt.show()

# %%
# scatter plot for Nagaland data

# %%
plt.figure()

plt.scatter(x[18:19],y[18:19])

plt.xlabel('Nagaland Crime')
plt.ylabel('Nagaland Literacy')

plt.show()

# %%
# scatter plot Odisha data

# %%
plt.figure()

plt.scatter(x[19:20],y[19:20])

plt.xlabel('Odisha Crime')
plt.ylabel('Odisha Literacy')

plt.show()

# %%
# scatter plot for Punjab data

# %%
plt.figure()

plt.scatter(x[20:21],y[20:21])

plt.xlabel('Punjab Crime')
plt.ylabel('Punjab Literacy')

plt.show()

# %%
# scatter plot for Rajasthan data

# %%
plt.figure()

plt.scatter(x[21:22],y[21:22])

plt.xlabel('Rajasthan Crime')
plt.ylabel('Rajasthan Literacy')

plt.show()

# %%
# scatter plot for Sikkim data

# %%
plt.figure()

plt.scatter(x[22:23],y[22:23])

plt.xlabel('Sikkim Crime')
plt.ylabel('Sikkim Literacy')

plt.show()

# %%
# scatter plot for Tamil Nadu data

# %%
plt.figure()

plt.scatter(x[23:24],y[23:24])

plt.xlabel('Tamil Nadu Crime')
plt.ylabel('Tamil Nadu Literacy')

plt.show()

# %%
# scatter plot for Telangana data

# %%
plt.figure()

plt.scatter(x[24:25],y[24:25])

plt.xlabel('Telangana Crime')
plt.ylabel('Telangana Literacy')

plt.show()

# %%
# scatter plot Tripura data

# %%
plt.figure()

plt.scatter(x[25:26],y[25:26])

plt.xlabel('Tripura Crime')
plt.ylabel('Tripura Literacy')

plt.show()

# %%
# scatter plot for Uttar Pradesh data

# %%
plt.figure()

plt.scatter(x[26:27],y[26:27])

plt.xlabel('Uttar Pradesh Crime')
plt.ylabel('Uttar Pradesh Literacy')

plt.show()

# %%
# scatter plot for Uttarakhand data

# %%
plt.figure()

plt.scatter(x[27:28],y[27:28])

plt.xlabel('Uttarakhand Crime')
plt.ylabel('Uttarakhand Literacy')

plt.show()

# %%
# scatter plot for West Bengal data

# %%
plt.figure()

plt.scatter(x[28:29],y[28:29])

plt.xlabel('West Bengal Crime')
plt.ylabel('West Bengal Literacy')

plt.show()

# %%
# scatter plot for Andman & Nicobar Island data

# %%
plt.figure()

plt.scatter(x[29:30],y[29:30])

plt.xlabel('A & N Islands Crime')
plt.ylabel('A & N Islands Literacy')

plt.show()

# %%
# scatter plot for Chandigarh data

# %%
plt.figure()

plt.scatter(x[30:31],y[30:31])

plt.xlabel('Chandigarh Crime')
plt.ylabel('Chandigarh Literacy')

plt.show()

# %%
# scatter plot for Dadra & Nagar Haveli data

# %%
plt.figure()

plt.scatter(x[31:32],y[31:32])

plt.xlabel('D&N Haveli Crime')
plt.ylabel('D&N Haveli Literacy')

plt.show()

# %%
# scatter plot for Daman & Diu data

# %%
plt.figure()

plt.scatter(x[32:33],y[32:33])

plt.xlabel('Daman & Diu Crime')
plt.ylabel('Daman & Diu Literacy')

plt.show()

# %%
# scatter plot for Delhi data

# %%
plt.figure()

plt.scatter(x[33:34],y[33:34])

plt.xlabel('Delhi Crime')
plt.ylabel('Delhi Literacy')

plt.show()

# %%
# scatter plot for Lakshadweep data

# %%
plt.figure()

plt.scatter(x[34:35],y[34:35])

plt.xlabel('Lakshadweep Crime')
plt.ylabel('Lakshadweep Literacy')

plt.show()

# %%
# scatter plot for Pudducherry data

# %%
plt.figure()

plt.scatter(x[35:],y[35:])

plt.xlabel('Puducherry Crime')
plt.ylabel('Puducherry Literacy')

plt.show()

# %%
# 2.2 - Analysis of the type of crime vs each state vs Literacy rate.

# %%
# importing dataset of crimes happened between 2001 - 2012

# %%
crime_type = pd.read_csv('01_District_wise_crimes_committed_IPC_2001_2012.csv')

crime_type
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
# improting literacy rate of India (state-wise)

# %%
literacy1
# Out:
#            Category Country/ States/ Union Territories Name  \
# 0           Country                                   INDIA
# 1             State                          Andhra Pradesh
# 2             State                       Arunachal Pradesh
# 3             State                                   Assam
# 4             State                                   Bihar
# 5             State                            Chhattisgarh
# 6             State                                     Goa
# 7             State                                 Gujarat
# 8             State                                 Haryana
# 9             State                        Himachal Pradesh
# 10            State                         Jammu & Kashmir
# 11            State                               Jharkhand
# 12            State                               Karnataka
# 13            State                                  Kerala
# 14            State                          Madhya Pradesh
# ...

# %%
# plotting scatter plot of crimes and literacy rate of different state individually

# %%
# scatter plot for Andhra Pradesh literacy vs crimes

# %%
# extracting only Andhra Pradesh crime data from the above table(crime_type)

# %%
andhra_crime = crime_type[28:29]
andhra_crime
# Out:
#           STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 28  ANDHRA PRADESH    TOTAL  2001    2602               1555
#
#     CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 28                                        136   871               0
#
#     OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 28         871                    1182  ...    872               34947
#
#     DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 28           420                                               3544
#
#     INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 28                        2271                                 5791
#
#     IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 28                                            7                         7400
#
#     OTHER IPC CRIMES  TOTAL IPC CRIMES
# 28             34344            130089
#
# [1 rows x 33 columns]

# %%
andhra_crime = andhra_crime['TOTAL IPC CRIMES']
andhra_crime
# Out:
# 28    130089
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Andhra Pradesh from above table(literacy1)

# %%
andhra_literacy = literacy1[1:2]
andhra_literacy
# Out:
#   Category Country/ States/ Union Territories Name  \
# 1    State                          Andhra Pradesh
#
#    Literacy Rate (Persons) - Total - 2001  \
# 1                                    60.5
#
#    Literacy Rate (Persons) - Total - 2011  \
# 1                                    67.0
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 1                                    54.5
#
#    Literacy Rate (Persons) - Rural - 2011  \
# 1                                    60.4
#
#    Literacy Rate (Persons) - Urban - 2001  \
# 1                                    76.1
#
#    Literacy Rate (Persons) - Urban - 2011
# 1                                    80.1

# %%
andhra_literacy = andhra_literacy['Literacy Rate (Persons) - Total - 2001']
andhra_literacy
# Out:
# 1    60.5
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(andhra_crime,andhra_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Arunachal Pradesh for crime vs literacy

# %%
# extracting crime data for Arunachal Pradesh from above table(crime_type)

# %%
arunachal_crime = crime_type[42:43]
arunachal_crime
# Out:
#              STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 42  ARUNACHAL PRADESH    TOTAL  2001      83                 53
#
#     CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 42                                          3    33               0
#
#     OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 42          33                      83  ...     13                 466
#
#     DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 42             0                                                 78
#
#     INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 42                           3                                   11
#
#     IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 42                                            0                            0
#
#     OTHER IPC CRIMES  TOTAL IPC CRIMES
# 42               618              2342
#
# [1 rows x 33 columns]

# %%
arunachal_crime = arunachal_crime['TOTAL IPC CRIMES']
arunachal_crime
# Out:
# 42    2342
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy rate for Arunachal Pradesh from above table(literacy1)

# %%
arunachal_literacy = literacy1[2:3]
arunachal_literacy
# Out:
#   Category Country/ States/ Union Territories Name  \
# 2    State                       Arunachal Pradesh
#
#    Literacy Rate (Persons) - Total - 2001  \
# 2                                    54.3
#
#    Literacy Rate (Persons) - Total - 2011  \
# 2                                    65.4
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 2                                    47.8
#
#    Literacy Rate (Persons) - Rural - 2011  \
# 2                                    59.9
#
#    Literacy Rate (Persons) - Urban - 2001  \
# 2                                    78.3
#
#    Literacy Rate (Persons) - Urban - 2011
# 2                                    82.9

# %%
arunachal_literacy = arunachal_literacy['Literacy Rate (Persons) - Total - 2001']
arunachal_literacy
# Out:
# 2    54.3
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(arunachal_crime,arunachal_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Assam for literacy vs crime

# %%
# extracting crime data for Assam from above table(crime_type)

# %%
assam_crime = crime_type[70:71]
assam_crime
# Out:
#    STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 70    ASSAM    TOTAL  2001    1356                481
#
#     CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 70                                         40   817               0
#
#     OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 70         817                    1480  ...    441                5805
#
#     DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 70            59                                                850
#
#     INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 70                           4                                 1248
#
#     IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 70                                            0                         2010
#
#     OTHER IPC CRIMES  TOTAL IPC CRIMES
# 70              9315             36877
#
# [1 rows x 33 columns]

# %%
assam_crime = assam_crime['TOTAL IPC CRIMES']
assam_crime
# Out:
# 70    36877
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Assam from above table(literacy1)

# %%
assam_literacy = literacy1[3:4]
assam_literacy
# Out:
#   Category Country/ States/ Union Territories Name  \
# 3    State                                   Assam
#
#    Literacy Rate (Persons) - Total - 2001  \
# 3                                    63.3
#
#    Literacy Rate (Persons) - Total - 2011  \
# 3                                    72.2
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 3                                    59.7
#
#    Literacy Rate (Persons) - Rural - 2011  \
# 3                                    69.3
#
#    Literacy Rate (Persons) - Urban - 2001  \
# 3                                    85.3
#
#    Literacy Rate (Persons) - Urban - 2011
# 3                                    88.5

# %%
assam_literacy = assam_literacy['Literacy Rate (Persons) - Total - 2001']
assam_literacy
# Out:
# 3    63.3
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(assam_crime,assam_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Bihar crimes vs literacy

# %%
# extracting crime data for Bihar from above table(crime_type)

# %%
bihar_crime = crime_type[115:116]
bihar_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 115    BIHAR    TOTAL  2001    3643               3419
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 115                                        250   888               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 115         888                    2159  ...    502                7544
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 115           859                                                562
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 115                          21                                 1558
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 115                                           83                         2406
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 115             36667             88432
#
# [1 rows x 33 columns]

# %%
bihar_crime = bihar_crime['TOTAL IPC CRIMES']
bihar_crime
# Out:
# 115    88432
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Bihar from above table(literacy1)

# %%
bihar_literacy = literacy1[4:5]
bihar_literacy
# Out:
#   Category Country/ States/ Union Territories Name  \
# 4    State                                   Bihar
#
#    Literacy Rate (Persons) - Total - 2001  \
# 4                                    47.0
#
#    Literacy Rate (Persons) - Total - 2011  \
# 4                                    61.8
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 4                                    43.9
#
#    Literacy Rate (Persons) - Rural - 2011  \
# 4                                    59.8
#
#    Literacy Rate (Persons) - Urban - 2001  \
# 4                                    71.9
#
#    Literacy Rate (Persons) - Urban - 2011
# 4                                    76.9

# %%
bihar_literacy = bihar_literacy['Literacy Rate (Persons) - Total - 2001']
bihar_literacy
# Out:
# 4    47.0
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(bihar_crime,bihar_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Chattisgarh crimes vs literacy

# %%
# extracting crime data for Chattisgarh from above table(crime_type)

# %%
chattisgarh_crime = crime_type[135:136]
chattisgarh_crime
# Out:
#          STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 135  CHHATTISGARH    TOTAL  2001     880                529
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 135                                         45   959               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 135         959                     207  ...    215                5477
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 135            70                                               1763
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 135                         161                                  840
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 135                                            0                          689
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 135             15790             38460
#
# [1 rows x 33 columns]

# %%
chattisgarh_crime = chattisgarh_crime['TOTAL IPC CRIMES']
chattisgarh_crime
# Out:
# 135    38460
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Chattisgarh from above table(literacy1)

# %%
chattisgarh_literacy = literacy1[5:6]
chattisgarh_literacy
# Out:
#   Category Country/ States/ Union Territories Name  \
# 5    State                            Chhattisgarh
#
#    Literacy Rate (Persons) - Total - 2001  \
# 5                                    64.7
#
#    Literacy Rate (Persons) - Total - 2011  \
# 5                                    70.3
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 5                                    60.5
#
#    Literacy Rate (Persons) - Rural - 2011  \
# 5                                    66.0
#
#    Literacy Rate (Persons) - Urban - 2001  \
# 5                                    80.6
#
#    Literacy Rate (Persons) - Urban - 2011
# 5                                    84.0

# %%
chattisgarh_literacy = chattisgarh_literacy['Literacy Rate (Persons) - Total - 2001']
chattisgarh_literacy
# Out:
# 5    64.7
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(chattisgarh_crime,chattisgarh_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Goa crimes vs literacy

# %%
# extracting crime data for Goa from above table(crime_type)

# %%
goa_crime = crime_type[138:139]
goa_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 138      GOA    TOTAL  2001      36                 30
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 138                                          5    12               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 138          12                       9  ...     16                 174
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 138             2                                                 17
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 138                           7                                   11
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 138                                            0                          191
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 138               697              2341
#
# [1 rows x 33 columns]

# %%
goa_crime = goa_crime['TOTAL IPC CRIMES']
goa_crime
# Out:
# 138    2341
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Goa from above table(literacy1)

# %%
goa_literacy = literacy1[6:7]
goa_literacy
# Out:
#   Category Country/ States/ Union Territories Name  \
# 6    State                                     Goa
#
#    Literacy Rate (Persons) - Total - 2001  \
# 6                                    82.0
#
#    Literacy Rate (Persons) - Total - 2011  \
# 6                                    88.7
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 6                                    79.7
#
#    Literacy Rate (Persons) - Rural - 2011  \
# 6                                    86.6
#
#    Literacy Rate (Persons) - Urban - 2001  \
# 6                                    84.4
#
#    Literacy Rate (Persons) - Urban - 2011
# 6                                    90.0

# %%
goa_literacy = goa_literacy['Literacy Rate (Persons) - Total - 2001']
goa_literacy
# Out:
# 6    82.0
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(goa_crime,goa_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatterplot for Gujarat crimes vs literacy

# %%
# extracting crime data for Gujarat from above table(crime_type)

# %%
gujarat_crime = crime_type[169:170]
gujarat_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 169  GUJARAT    TOTAL  2001    1226                537
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 169                                         94   286               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 169         286                     998  ...    449               13760
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 169            67                                                756
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 169                         111                                 3667
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 169                                            0                         2924
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 169             50719            103419
#
# [1 rows x 33 columns]

# %%
gujarat_crime = gujarat_crime['TOTAL IPC CRIMES']
gujarat_crime
# Out:
# 169    103419
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Gujarat from above table(literacy1)

# %%
gujarat_literacy = literacy1[7:8]
gujarat_literacy
# Out:
#   Category Country/ States/ Union Territories Name  \
# 7    State                                 Gujarat
#
#    Literacy Rate (Persons) - Total - 2001  \
# 7                                    69.1
#
#    Literacy Rate (Persons) - Total - 2011  \
# 7                                    78.0
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 7                                    61.3
#
#    Literacy Rate (Persons) - Rural - 2011  \
# 7                                    71.7
#
#    Literacy Rate (Persons) - Urban - 2001  \
# 7                                    81.8
#
#    Literacy Rate (Persons) - Urban - 2011
# 7                                    86.3

# %%
gujarat_literacy = gujarat_literacy['Literacy Rate (Persons) - Total - 2001']
gujarat_literacy
# Out:
# 7    69.1
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(gujarat_crime,gujarat_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Haryana crime vs literacy

# %%
# extracting crime data for Haryana from above table(crime_type)

# %%
haryana_crime = crime_type[190:191]
haryana_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 190  HARYANA    TOTAL  2001     781                467
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 190                                         78   398               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 190         398                     449  ...    203                4744
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 190           285                                                478
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 190                         401                                 1513
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 190                                            0                          856
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 190             15906             38759
#
# [1 rows x 33 columns]

# %%
haryana_crime = haryana_crime['TOTAL IPC CRIMES']
haryana_crime
# Out:
# 190    38759
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Haryana from above table(literacy1)

# %%
haryana_literacy = literacy1[8:9]
haryana_literacy
# Out:
#   Category Country/ States/ Union Territories Name  \
# 8    State                                 Haryana
#
#    Literacy Rate (Persons) - Total - 2001  \
# 8                                    67.9
#
#    Literacy Rate (Persons) - Total - 2011  \
# 8                                    75.6
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 8                                    63.2
#
#    Literacy Rate (Persons) - Rural - 2011  \
# 8                                    71.4
#
#    Literacy Rate (Persons) - Urban - 2001  \
# 8                                    79.2
#
#    Literacy Rate (Persons) - Urban - 2011
# 8                                    83.1

# %%
haryana_literacy = haryana_literacy['Literacy Rate (Persons) - Total - 2001']
haryana_literacy
# Out:
# 8    67.9
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(haryana_crime,haryana_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatterplot for Himachal Pradesh crimes vs literacy

# %%
# extracting crime data for Himachal Pradesh from above table(crime_type)

# %%
himachal_crime = crime_type[204:205]
himachal_crime
# Out:
#              STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 204  HIMACHAL PRADESH    TOTAL  2001     119                 75
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 204                                         11   124               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 204         124                     126  ...    134                1403
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 204            10                                                310
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 204                          14                                  317
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 204                                            0                          483
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 204              6052             11499
#
# ...

# %%
himachal_crime = himachal_crime['TOTAL IPC CRIMES']
himachal_crime
# Out:
# 204    11499
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Himachal Pradesh from above table(literacy1)

# %%
himachal_literacy = literacy1[9:10]
himachal_literacy
# Out:
#   Category Country/ States/ Union Territories Name  \
# 9    State                        Himachal Pradesh
#
#    Literacy Rate (Persons) - Total - 2001  \
# 9                                    76.5
#
#    Literacy Rate (Persons) - Total - 2011  \
# 9                                    82.8
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 9                                    75.1
#
#    Literacy Rate (Persons) - Rural - 2011  \
# 9                                    81.9
#
#    Literacy Rate (Persons) - Urban - 2001  \
# 9                                    88.9
#
#    Literacy Rate (Persons) - Urban - 2011
# 9                                    91.1

# %%
himachal_literacy = himachal_literacy['Literacy Rate (Persons) - Total - 2001']
himachal_literacy
# Out:
# 9    76.5
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(himachal_crime,himachal_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Jammu & Kashmir crimes vs literacy

# %%
# extracting crime data for Jammu & Kashmir from above table(crime_type)

# %%
jammu_crime = crime_type[228:229]
jammu_crime
# Out:
#             STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 228  JAMMU & KASHMIR    TOTAL  2001    1075               1474
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 228                                         33   169               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 228         169                     606  ...    437                 318
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 228            13                                                622
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 228                         288                                   50
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 228                                            0                          357
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 228              9046             19505
#
# ...

# %%
jammu_crime = jammu_crime['TOTAL IPC CRIMES']
jammu_crime
# Out:
# 228    19505
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Jammu & Kashmir from above table(literacy1)

# %%
jammu_literacy = literacy1[10:11]
jammu_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 10    State                         Jammu & Kashmir
#
#     Literacy Rate (Persons) - Total - 2001  \
# 10                                    55.5
#
#     Literacy Rate (Persons) - Total - 2011  \
# 10                                    67.2
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 10                                    49.8
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 10                                    63.2
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 10                                    71.9
#
#     Literacy Rate (Persons) - Urban - 2011
# 10                                    77.1

# %%
jammu_literacy = jammu_literacy['Literacy Rate (Persons) - Total - 2001']
jammu_literacy
# Out:
# 10    55.5
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(jammu_crime,jammu_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Jharkhand crimes vs literacy

# %%
# extracting crime data for Jharkhand from above table(crime_type)

# %%
jharkhand_crime = crime_type[253:254]
jharkhand_crime
# Out:
#       STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 253  JHARKHAND    TOTAL  2001    1507                866
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 253                                        143   567               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 253         567                     441  ...    165                2254
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 253           217                                                297
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 253                           5                                  484
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 253                                            2                          420
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 253              8777             25447
#
# [1 rows x 33 columns]

# %%
jharkhand_crime = jharkhand_crime['TOTAL IPC CRIMES']
jharkhand_crime
# Out:
# 253    25447
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Jharkhand from above table(literacy1)

# %%
jharkhand_literacy = literacy1[11:12]
jharkhand_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 11    State                               Jharkhand
#
#     Literacy Rate (Persons) - Total - 2001  \
# 11                                    53.6
#
#     Literacy Rate (Persons) - Total - 2011  \
# 11                                    66.4
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 11                                    45.7
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 11                                    61.1
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 11                                    79.1
#
#     Literacy Rate (Persons) - Urban - 2011
# 11                                    82.3

# %%
jharkhand_literacy = jharkhand_literacy['Literacy Rate (Persons) - Total - 2001']
jharkhand_literacy
# Out:
# 11    53.6
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(jharkhand_crime,jharkhand_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatterplot for Karnataka crimes vs literacy

# %%
# extracting crime data for Karnataka from above table(crime_type)

# %%
karnataka_crime = crime_type[285:286]
karnataka_crime
# Out:
#       STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 285  KARNATAKA    TOTAL  2001    1626               1475
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 285                                         74   293               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 285         293                     559  ...    352               23285
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 285           220                                               1665
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 285                          81                                 1755
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 285                                            0                          100
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 285             47301            109098
#
# [1 rows x 33 columns]

# %%
karnataka_crime = karnataka_crime['TOTAL IPC CRIMES']
karnataka_crime
# Out:
# 285    109098
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Karnataka from above table(literacy1)

# %%
karnataka_literacy = literacy1[12:13]
karnataka_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 12    State                               Karnataka
#
#     Literacy Rate (Persons) - Total - 2001  \
# 12                                    66.6
#
#     Literacy Rate (Persons) - Total - 2011  \
# 12                                    75.4
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 12                                    59.3
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 12                                    68.7
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 12                                    80.6
#
#     Literacy Rate (Persons) - Urban - 2011
# 12                                    85.8

# %%
karnataka_literacy = karnataka_literacy['Literacy Rate (Persons) - Total - 2001']
karnataka_literacy
# Out:
# 12    66.6
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(karnataka_crime,karnataka_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Kerala crimes vs literacy

# %%
# extracting crime data for Kerala from above table(crime_type)

# %%
kerala_crime = crime_type[302:303]
kerala_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 302   KERALA    TOTAL  2001     472                615
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 302                                        111   562               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 302         562                     183  ...    768               19829
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 302            27                                               1942
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 302                          81                                 2561
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 302                                            0                            0
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 302             54544            103847
#
# [1 rows x 33 columns]

# %%
kerala_crime = kerala_crime['TOTAL IPC CRIMES']
kerala_crime
# Out:
# 302    103847
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Kerala from above table(literacy1)

# %%
kerala_literacy = literacy1[13:14]
kerala_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 13    State                                  Kerala
#
#     Literacy Rate (Persons) - Total - 2001  \
# 13                                    90.9
#
#     Literacy Rate (Persons) - Total - 2011  \
# 13                                    94.0
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 13                                    90.0
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 13                                    93.0
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 13                                    93.2
#
#     Literacy Rate (Persons) - Urban - 2011
# 13                                    95.1

# %%
kerala_literacy = kerala_literacy['Literacy Rate (Persons) - Total - 2001']
kerala_literacy
# Out:
# 13    90.9
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(kerala_crime,kerala_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Madhya Pradesh crimes vs literacy

# %%
# extracting crime data for Madhya Pradesh from above table(crime_type)

# %%
mp_crime = crime_type[351:352]
mp_crime
# Out:
#            STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 351  MADHYA PRADESH    TOTAL  2001    2425               2870
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 351                                        125  2851               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 351        2851                     956  ...   1014               30895
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 351           609                                               7063
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 351                         751                                 2562
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 351                                            0                         3297
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 351             85143            181741
#
# ...

# %%
mp_crime = mp_crime['TOTAL IPC CRIMES']
mp_crime
# Out:
# 351    181741
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Madhya Pradesh from above table (literacy1)

# %%
mp_literacy = literacy1[14:15]
mp_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 14    State                          Madhya Pradesh
#
#     Literacy Rate (Persons) - Total - 2001  \
# 14                                    63.7
#
#     Literacy Rate (Persons) - Total - 2011  \
# 14                                    69.3
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 14                                    57.8
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 14                                    63.9
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 14                                    79.4
#
#     Literacy Rate (Persons) - Urban - 2011
# 14                                    82.8

# %%
mp_literacy = mp_literacy['Literacy Rate (Persons) - Total - 2001']
mp_literacy
# Out:
# 14    63.7
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(mp_crime,mp_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Maharashtra crimes vs literacy

# %%
# extractiing crime data for Maharashtra from above table(crime_type)

# %%
mh_crime = crime_type[397:398]
mh_crime
# Out:
#         STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 397  MAHARASHTRA    TOTAL  2001    2839               1454
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 397                                        101  1302               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 397        1302                     985  ...   1208               30212
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 397           308                                               2823
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 397                        1120                                 6090
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 397                                            1                         8993
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 397             42963            171233
#
# [1 rows x 33 columns]

# %%
mh_crime = mh_crime['TOTAL IPC CRIMES']
mh_crime
# Out:
# 397    171233
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Maharashtra from above table(literacy1)

# %%
mh_literacy = literacy1[15:16]
mh_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 15    State                             Maharashtra
#
#     Literacy Rate (Persons) - Total - 2001  \
# 15                                    76.9
#
#     Literacy Rate (Persons) - Total - 2011  \
# 15                                    82.3
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 15                                    70.4
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 15                                    77.0
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 15                                    85.5
#
#     Literacy Rate (Persons) - Urban - 2011
# 15                                    88.7

# %%
mh_literacy = mh_literacy['Literacy Rate (Persons) - Total - 2001']
mh_literacy
# Out:
# 15    76.9
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(mh_crime,mh_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Manipur crimes vs literacy

# %%
# extracting crime data for Manipur from above table(crime_type)

# %%
manipur_crime = crime_type[407:408]
manipur_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 407  MANIPUR    TOTAL  2001     209                168
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 407                                          5    20               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 407          20                      94  ...     64                 201
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 407             0                                                 21
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 407                           0                                    5
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 407                                            0                            7
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 407              1097              2489
#
# [1 rows x 33 columns]

# %%
manipur_crime = manipur_crime['TOTAL IPC CRIMES']
manipur_crime
# Out:
# 407    2489
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Manipur from above table(literacy1)

# %%
manipur_literacy = literacy1[16:17]
manipur_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 16    State                                 Manipur
#
#     Literacy Rate (Persons) - Total - 2001  \
# 16                                    70.5
#
#     Literacy Rate (Persons) - Total - 2011  \
# 16                                    76.9
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 16                                    67.3
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 16                                    73.4
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 16                                    79.3
#
#     Literacy Rate (Persons) - Urban - 2011
# 16                                    85.4

# %%
manipur_literacy = manipur_literacy['Literacy Rate (Persons) - Total - 2001']
manipur_literacy
# Out:
# 16    70.5
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(manipur_crime,manipur_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot from Meghalaya crimes vs literacy

# %%
# extracting crime data for Meghalaya from above table (crime_type)

# %%
meghalaya_crime = crime_type[415:416]
meghalaya_crime
# Out:
#       STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 415  MEGHALAYA    TOTAL  2001     164                 47
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 415                                          2    26               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 415          26                      55  ...     26                 102
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 415             0                                                 25
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 415                           0                                    4
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 415                                            0                            0
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 415               511              1687
#
# [1 rows x 33 columns]

# %%
meghalaya_crime = meghalaya_crime['TOTAL IPC CRIMES']
meghalaya_crime
# Out:
# 415    1687
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Meghalaya from above table(literacy1)

# %%
meghalaya_literacy = literacy1[17:18]
meghalaya_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 17    State                               Meghalaya
#
#     Literacy Rate (Persons) - Total - 2001  \
# 17                                    62.6
#
#     Literacy Rate (Persons) - Total - 2011  \
# 17                                    74.4
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 17                                    56.3
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 17                                    69.9
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 17                                    86.3
#
#     Literacy Rate (Persons) - Urban - 2011
# 17                                    90.8

# %%
meghalaya_literacy = meghalaya_literacy['Literacy Rate (Persons) - Total - 2001']
meghalaya_literacy
# Out:
# 17    62.6
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(meghalaya_crime,meghalaya_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Mizoram crimes vs literacy

# %%
# extracting crime data for Mizoram from above table(crime_type)

# %%
mizoram_crime = crime_type[424:425]
mizoram_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 424  MIZORAM    TOTAL  2001      31                 15
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 424                                          5    52               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 424          52                       2  ...     24                  94
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 424             0                                                 52
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 424                           0                                   16
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 424                                            3                           23
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 424               499              2246
#
# [1 rows x 33 columns]

# %%
mizoram_crime = mizoram_crime['TOTAL IPC CRIMES']
mizoram_crime
# Out:
# 424    2246
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Mizoram from above table(literacy1)

# %%
mizoram_literacy = literacy1[18:19]
mizoram_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 18    State                                 Mizoram
#
#     Literacy Rate (Persons) - Total - 2001  \
# 18                                    88.8
#
#     Literacy Rate (Persons) - Total - 2011  \
# 18                                    91.3
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 18                                    81.3
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 18                                    84.1
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 18                                    96.1
#
#     Literacy Rate (Persons) - Urban - 2011
# 18                                    97.6

# %%
mizoram_literacy = mizoram_literacy['Literacy Rate (Persons) - Total - 2001']
mizoram_literacy
# Out:
# 18    88.8
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(mizoram_crime,mizoram_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Nagaland crimes vs literacy

# %%
# extracting crime data for Nagaland from above table(crime_type)

# %%
nagaland_crime = crime_type[435:436]
nagaland_crime
# Out:
#      STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 435  NAGALAND    TOTAL  2001     101                 39
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 435                                          9    17               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 435          17                      23  ...      1                  37
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 435             0                                                  6
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 435                           0                                    0
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 435                                            0                           19
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 435               363              1234
#
# [1 rows x 33 columns]

# %%
nagaland_crime = nagaland_crime['TOTAL IPC CRIMES']
nagaland_crime
# Out:
# 435    1234
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Nagaland from above table(literacy1)

# %%
nagaland_literacy = literacy1[19:20]
nagaland_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 19    State                                Nagaland
#
#     Literacy Rate (Persons) - Total - 2001  \
# 19                                    66.6
#
#     Literacy Rate (Persons) - Total - 2011  \
# 19                                    79.6
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 19                                    62.8
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 19                                    75.3
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 19                                    84.7
#
#     Literacy Rate (Persons) - Urban - 2011
# 19                                    89.6

# %%
nagaland_literacy = nagaland_literacy['Literacy Rate (Persons) - Total - 2001']
nagaland_literacy
# Out:
# 19    66.6
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(nagaland_crime,nagaland_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Odisha crimes vs literacy

# %%
# extracting crime data for Odisha from above table(crime_type)

# %%
odisha_crime = crime_type[470:471]
odisha_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 470   ODISHA    TOTAL  2001     987               1151
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 470                                         53   790               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 470         790                     522  ...    423                4367
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 470           294                                               1655
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 470                         458                                 1266
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 470                                            0                         1589
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 470             20810             46661
#
# [1 rows x 33 columns]

# %%
odisha_crime = odisha_crime['TOTAL IPC CRIMES']
odisha_crime
# Out:
# 470    46661
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Odisha from above table(literacy1)

# %%
odisha_literacy = literacy1[20:21]
odisha_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 20    State                                  Odisha
#
#     Literacy Rate (Persons) - Total - 2001  \
# 20                                    63.1
#
#     Literacy Rate (Persons) - Total - 2011  \
# 20                                    72.9
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 20                                    59.8
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 20                                    70.2
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 20                                    80.8
#
#     Literacy Rate (Persons) - Urban - 2011
# 20                                    85.7

# %%
odisha_literacy = odisha_literacy['Literacy Rate (Persons) - Total - 2001']
odisha_literacy
# Out:
# 20    63.1
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(odisha_crime,odisha_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Punjab crimes vs literacy

# %%
# extracting crime data for Punjab from above table(crime_type)

# %%
punjab_crime = crime_type[495:496]
punjab_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 495   PUNJAB    TOTAL  2001     738                789
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 495                                         80   298               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 495         298                     513  ...     63                3996
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 495           159                                                372
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 495                          47                                 1128
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 495                                            0                         2154
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 495              9204             27774
#
# [1 rows x 33 columns]

# %%
punjab_crime = punjab_crime['TOTAL IPC CRIMES']
punjab_crime
# Out:
# 495    27774
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Punjab from above table(literacy1)

# %%
punjab_literacy = literacy1[21:22]
punjab_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 21    State                                  Punjab
#
#     Literacy Rate (Persons) - Total - 2001  \
# 21                                    69.7
#
#     Literacy Rate (Persons) - Total - 2011  \
# 21                                    75.8
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 21                                    64.7
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 21                                    71.4
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 21                                    79.1
#
#     Literacy Rate (Persons) - Urban - 2011
# 21                                    83.2

# %%
punjab_literacy = punjab_literacy['Literacy Rate (Persons) - Total - 2001']
punjab_literacy
# Out:
# 21    69.7
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(punjab_crime,punjab_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Rajasthan crimes vs literacy

# %%
# extracting crime data for Rajasthan from above table(crime_type)

# %%
rajasthan_crime = crime_type[529:530]
rajasthan_crime
# Out:
#       STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 529  RAJASTHAN    TOTAL  2001    1259               1923
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 529                                         63  1049               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 529        1049                    2718  ...   1092               27485
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 529           376                                               2878
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 529                          56                                 5532
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 529                                            1                         4221
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 529             62347            155185
#
# [1 rows x 33 columns]

# %%
rajasthan_crime = rajasthan_crime['TOTAL IPC CRIMES']
rajasthan_crime
# Out:
# 529    155185
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Rajasthan from above table(literacy1)

# %%
rajasthan_literacy = literacy1[22:23]
rajasthan_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 22    State                               Rajasthan
#
#     Literacy Rate (Persons) - Total - 2001  \
# 22                                    60.4
#
#     Literacy Rate (Persons) - Total - 2011  \
# 22                                    66.1
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 22                                    55.3
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 22                                    61.4
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 22                                    76.2
#
#     Literacy Rate (Persons) - Urban - 2011
# 22                                    79.7

# %%
rajasthan_literacy =  rajasthan_literacy['Literacy Rate (Persons) - Total - 2001']
rajasthan_literacy
# Out:
# 22    60.4
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(rajasthan_crime,rajasthan_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Sikkim crimes vs literacy

# %%
# extracting crime data for Sikkim from above table(crime_type)

# %%
sikkim_crime = crime_type[534:535]
sikkim_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 534   SIKKIM    TOTAL  2001      19                 11
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 534                                          7     8               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 534           8                       6  ...      1                  35
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 534             0                                                  0
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 534                          14                                    0
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 534                                            0                            7
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 534               166               444
#
# [1 rows x 33 columns]

# %%
sikkim_crime = sikkim_crime['TOTAL IPC CRIMES']
sikkim_crime
# Out:
# 534    444
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Sikkim from above table(literacy1)

# %%
sikkim_literacy = literacy1[23:24]
sikkim_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 23    State                                  Sikkim
#
#     Literacy Rate (Persons) - Total - 2001  \
# 23                                    68.8
#
#     Literacy Rate (Persons) - Total - 2011  \
# 23                                    81.4
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 23                                    66.8
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 23                                    78.9
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 23                                    83.9
#
#     Literacy Rate (Persons) - Urban - 2011
# 23                                    88.7

# %%
sikkim_literacy = sikkim_literacy['Literacy Rate (Persons) - Total - 2001']
sikkim_literacy
# Out:
# 23    68.8
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(sikkim_crime,sikkim_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Tamil Nadu crimes vs literacy

# %%
# extracting crime data for Tamil Nadu from above table(crime_type)

# %%
tn_crime = crime_type[573:574]
tn_crime
# Out:
#        STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 573  TAMIL NADU    TOTAL  2001    1662               2204
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 573                                         19   423               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 573         423                     952  ...    980               28429
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 573           191                                               1773
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 573                        1012                                  815
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 573                                           14                         8550
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 573             76468            154801
#
# [1 rows x 33 columns]

# %%
tn_crime = tn_crime['TOTAL IPC CRIMES']
tn_crime
# Out:
# 573    154801
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Tamil Nadu from above table(literacy1)

# %%
tn_literacy = literacy1[24:25]
tn_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 24    State                              Tamil Nadu
#
#     Literacy Rate (Persons) - Total - 2001  \
# 24                                    73.5
#
#     Literacy Rate (Persons) - Total - 2011  \
# 24                                    80.1
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 24                                    66.2
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 24                                    73.5
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 24                                    82.5
#
#     Literacy Rate (Persons) - Urban - 2011
# 24                                    87.0

# %%
tn_literacy = tn_literacy['Literacy Rate (Persons) - Total - 2001']
tn_literacy
# Out:
# 24    73.5
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(tn_crime,tn_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Tripura crimes vs literacy

# %%
# extracting crime data for Tripura from above table (crime_type)

# %%
tripura_crime = crime_type[578:579]
tripura_crime
# Out:
#     STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 578  TRIPURA    TOTAL  2001     240                 25
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 578                                          0   102               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 578         102                      93  ...     31                 412
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 578            16                                                 58
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 578                           0                                  227
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 578                                            0                           31
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 578               855              2801
#
# [1 rows x 33 columns]

# %%
tripura_crime = tripura_crime['TOTAL IPC CRIMES']
tripura_crime
# Out:
# 578    2801
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Tripura from above table (literacy1)

# %%
tripura_literacy = literacy1[25:26]
tripura_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 25    State                                 Tripura
#
#     Literacy Rate (Persons) - Total - 2001  \
# 25                                    73.2
#
#     Literacy Rate (Persons) - Total - 2011  \
# 25                                    87.2
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 25                                    69.7
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 25                                    84.9
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 25                                    89.2
#
#     Literacy Rate (Persons) - Urban - 2011
# 25                                    93.5

# %%
tripura_literacy = tripura_literacy['Literacy Rate (Persons) - Total - 2001']
tripura_literacy
# Out:
# 25    73.2
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(tripura_crime,tripura_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Uttar Pradesh crimes vs literacy

# %%
# extracting crime data for Uttar Pradesh from above table(crime_type)

# %%
up_crime = crime_type[650:651]
up_crime
# Out:
#           STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 650  UTTAR PRADESH    TOTAL  2001    7601               7964
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 650                                       1186  1958               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 650        1958                    4330  ...    812               17816
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 650          2211                                               2870
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 650                        2575                                 7365
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 650                                            0                         7129
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 650             57839            178129
#
# ...

# %%
up_crime = up_crime['TOTAL IPC CRIMES']
up_crime
# Out:
# 650    178129
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Uttar Pradesh from above table (literacy1)

# %%
up_literacy = literacy1[26:27]
up_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 26    State                           Uttar Pradesh
#
#     Literacy Rate (Persons) - Total - 2001  \
# 26                                    56.3
#
#     Literacy Rate (Persons) - Total - 2011  \
# 26                                    67.7
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 26                                    52.5
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 26                                    65.5
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 26                                    69.8
#
#     Literacy Rate (Persons) - Urban - 2011
# 26                                    75.1

# %%
up_literacy = up_literacy['Literacy Rate (Persons) - Total - 2001']
up_literacy
# Out:
# 26    56.3
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(up_crime,up_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Uttarakhand crimes vs literacy

# %%
# extracting crime data for Uttarakhand from above table(crime_type)

# %%
uttarakhand_crime = crime_type[664:665]
uttarakhand_crime
# Out:
#         STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 664  UTTARAKHAND    TOTAL  2001     316                279
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 664                                         38    74               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 664          74                     183  ...     30                 830
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 664            56                                                103
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 664                          84                                  301
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 664                                            0                          441
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 664              2227              8073
#
# [1 rows x 33 columns]

# %%
uttarakhand_crime = uttarakhand_crime['TOTAL IPC CRIMES']
uttarakhand_crime
# Out:
# 664    8073
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Uttarakhand from above table(literacy1)

# %%
uttarakhand_literacy = literacy1[27:28]
uttarakhand_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 27    State                             Uttarakhand
#
#     Literacy Rate (Persons) - Total - 2001  \
# 27                                    71.6
#
#     Literacy Rate (Persons) - Total - 2011  \
# 27                                    78.8
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 27                                    68.1
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 27                                    76.3
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 27                                    81.4
#
#     Literacy Rate (Persons) - Urban - 2011
# 27                                    84.5

# %%
uttarakhand_literacy = uttarakhand_literacy['Literacy Rate (Persons) - Total - 2001']
uttarakhand_literacy
# Out:
# 27    71.6
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(uttarakhand_crime,uttarakhand_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for West Bengal crimes vs literacy

# %%
# extracting crime data for West Bengal from above table(crime_type)

# %%
west_beng_crime = crime_type[688:689]
west_beng_crime
# Out:
#         STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 688  WEST BENGAL    TOTAL  2001    1594                449
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 688                                        581   709               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 688         709                     875  ...    102                3658
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 688           265                                                954
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 688                          48                                 3859
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 688                                            3                         2281
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 688             25260             61563
#
# [1 rows x 33 columns]

# %%
west_beng_crime = west_beng_crime['TOTAL IPC CRIMES']
west_beng_crime
# Out:
# 688    61563
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for West Bengal from above table(literacy1)

# %%
west_beng_literacy = literacy1[28:29]
west_beng_literacy
# Out:
#    Category Country/ States/ Union Territories Name  \
# 28    State                             West Bengal
#
#     Literacy Rate (Persons) - Total - 2001  \
# 28                                    68.6
#
#     Literacy Rate (Persons) - Total - 2011  \
# 28                                    76.3
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 28                                    63.4
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 28                                    72.1
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 28                                    81.2
#
#     Literacy Rate (Persons) - Urban - 2011
# 28                                    84.8

# %%
west_beng_literacy = west_beng_literacy['Literacy Rate (Persons) - Total - 2001']
west_beng_literacy
# Out:
# 28    68.6
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(west_beng_crime,west_beng_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Andman & Nicobar crimes vs literacy

# %%
# extracting crime data for Andman & Nicobar from above table(crime_type)

# %%
andman_crime = crime_type[691:692]
andman_crime
# Out:
#           STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 691  A & N ISLANDS    TOTAL  2001      13                  0
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 691                                          0     3               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 691           3                       2  ...      4                 118
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 691             0                                                 19
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 691                           1                                    9
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 691                                            0                            0
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 691               323               658
#
# ...

# %%
andman_crime = andman_crime['TOTAL IPC CRIMES']
andman_crime
# Out:
# 691    658
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Andman & Nicobar from above table(literacy1)

# %%
andman_literacy = literacy1[29:30]
andman_literacy
# Out:
#            Category Country/ States/ Union Territories Name  \
# 29  Union Territory                           A & N Islands
#
#     Literacy Rate (Persons) - Total - 2001  \
# 29                                    81.3
#
#     Literacy Rate (Persons) - Total - 2011  \
# 29                                    86.6
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 29                                    78.7
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 29                                    84.5
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 29                                    86.6
#
#     Literacy Rate (Persons) - Urban - 2011
# 29                                    90.1

# %%
andman_literacy = andman_literacy['Literacy Rate (Persons) - Total - 2001']
andman_literacy
# Out:
# 29    81.3
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(andman_crime,andman_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Chandigarh crimes vs literacy

# %%
# extracting crime data for Chandigarh from above table(crime_type)

# %%
chandigarh_crime = crime_type[693:694]
chandigarh_crime
# Out:
#        STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 693  CHANDIGARH    TOTAL  2001      15                 10
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 693                                          6    18               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 693          18                      56  ...      5                  95
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 693             3                                                 24
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 693                          15                                   36
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 693                                            0                            6
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 693               914              3397
#
# [1 rows x 33 columns]

# %%
chandigarh_crime = chandigarh_crime['TOTAL IPC CRIMES']
chandigarh_crime
# Out:
# 693    3397
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Chandigarh from above table(literacy1)

# %%
chandigarh_literacy = literacy1[30:31]
chandigarh_literacy
# Out:
#            Category Country/ States/ Union Territories Name  \
# 30  Union Territory                              Chandigarh
#
#     Literacy Rate (Persons) - Total - 2001  \
# 30                                    81.9
#
#     Literacy Rate (Persons) - Total - 2011  \
# 30                                    86.0
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 30                                    75.6
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 30                                    80.7
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 30                                    82.6
#
#     Literacy Rate (Persons) - Urban - 2011
# 30                                    86.2

# %%
chandigarh_literacy = chandigarh_literacy['Literacy Rate (Persons) - Total - 2001']
chandigarh_literacy
# Out:
# 30    81.9
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(chandigarh_crime,chandigarh_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Dadra & Nagra Haveli crimes vs literacy

# %%
# extracting crime data for Dadra & Nagra Haveli from above table(crime_type)

# %%
dadra_crime = crime_type[695:696]
dadra_crime
# Out:
#          STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 695  D & N HAVELI    TOTAL  2001       3                  2
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 695                                          0     6               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 695           6                       4  ...      1                  29
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 695             0                                                  7
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 695                           0                                    4
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 695                                            0                            0
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 695               183               350
#
# [1 rows x 33 columns]

# %%
dadra_crime = dadra_crime['TOTAL IPC CRIMES']
dadra_crime
# Out:
# 695    350
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Dadra & Nagra Haveli from above table(literacy1)

# %%
dadra_literacy = literacy1[31:32]
dadra_literacy
# Out:
#            Category Country/ States/ Union Territories Name  \
# 31  Union Territory                            D & N Haveli
#
#     Literacy Rate (Persons) - Total - 2001  \
# 31                                    57.6
#
#     Literacy Rate (Persons) - Total - 2011  \
# 31                                    76.2
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 31                                    49.3
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 31                                    64.1
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 31                                    84.4
#
#     Literacy Rate (Persons) - Urban - 2011
# 31                                    89.8

# %%
dadra_literacy = dadra_literacy['Literacy Rate (Persons) - Total - 2001']
dadra_literacy
# Out:
# 31    57.6
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(dadra_crime,dadra_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Daman & Diu crimes vs literacy

# %%
# extracting crime data for Daman & Diu from above table(crime_type)

# %%
daman_crime = crime_type[698:699]
daman_crime
# Out:
#         STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 698  DAMAN & DIU    TOTAL  2001       7                  5
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 698                                          0     0               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 698           0                       5  ...      3                  21
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 698             0                                                  0
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 698                           0                                    4
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 698                                            0                            0
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 698                73               239
#
# [1 rows x 33 columns]

# %%
daman_crime = daman_crime['TOTAL IPC CRIMES']
daman_crime
# Out:
# 698    239
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Daman & Diu from above table (literacy1)

# %%
daman_literacy = literacy1[32:33]
daman_literacy
# Out:
#            Category Country/ States/ Union Territories Name  \
# 32  Union Territory                             Daman & Diu
#
#     Literacy Rate (Persons) - Total - 2001  \
# 32                                    78.2
#
#     Literacy Rate (Persons) - Total - 2011  \
# 32                                    87.1
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 32                                    75.8
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 32                                    81.4
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 32                                    82.3
#
#     Literacy Rate (Persons) - Urban - 2011
# 32                                    89.0

# %%
daman_literacy = daman_literacy['Literacy Rate (Persons) - Total - 2001']
daman_literacy
# Out:
# 32    78.2
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(daman_crime,daman_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Delhi crimes vs literacy

# %%
# extracting crime data for Delhi from above table(crime_type)

# %%
delhi_crime = crime_type[711:712]
delhi_crime
# Out:
#      STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 711  DELHI UT     WEST  2001      70                 51
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 711                                         12    45               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 711          45                     151  ...      3                 252
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 711            18                                                 65
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 711                           2                                   22
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 711                                            0                            4
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 711              4151              7690
#
# [1 rows x 33 columns]

# %%
delhi_crime = delhi_crime['TOTAL IPC CRIMES']
delhi_crime
# Out:
# 711    7690
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Delhi from above table(literacy1)

# %%
delhi_literacy = literacy1[34:35]
delhi_literacy
# Out:
#            Category Country/ States/ Union Territories Name  \
# 34  Union Territory                            NCT of Delhi
#
#     Literacy Rate (Persons) - Total - 2001  \
# 34                                    81.7
#
#     Literacy Rate (Persons) - Total - 2011  \
# 34                                    86.2
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 34                                    78.1
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 34                                    81.9
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 34                                    81.9
#
#     Literacy Rate (Persons) - Urban - 2011
# 34                                    86.3

# %%
delhi_literacy = delhi_literacy['Literacy Rate (Persons) - Total - 2001']
delhi_literacy
# Out:
# 34    81.7
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(delhi_crime,delhi_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Lakshadweep crimes vs literacy

# %%
# extracting crime data for Lakshadweep from above table(crime_type)

# %%
laksh_crime = crime_type[713:714]
laksh_crime
# Out:
#         STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 713  LAKSHADWEEP    TOTAL  2001       1                  0
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 713                                          0     0               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 713           0                       0  ...      2                   3
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 713             0                                                  0
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 713                           0                                    0
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 713                                            0                            0
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 713                17                36
#
# [1 rows x 33 columns]

# %%
laksh_crime = laksh_crime['TOTAL IPC CRIMES']
laksh_crime
# Out:
# 713    36
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Lakshadweep from above table(literacy1)

# %%
laksh_literacy = literacy1[33:34]
laksh_literacy
# Out:
#            Category Country/ States/ Union Territories Name  \
# 33  Union Territory                             Lakshadweep
#
#     Literacy Rate (Persons) - Total - 2001  \
# 33                                    86.7
#
#     Literacy Rate (Persons) - Total - 2011  \
# 33                                    91.8
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 33                                    85.0
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 33                                    91.6
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 33                                    88.6
#
#     Literacy Rate (Persons) - Urban - 2011
# 33                                    91.9

# %%
laksh_literacy = laksh_literacy['Literacy Rate (Persons) - Total - 2001']
laksh_literacy
# Out:
# 33    86.7
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(laksh_crime,laksh_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()

# %%
# scatter plot for Puducherry crimes vs literacy

# %%
# extracting crime data for Puducherry from above table(crime_type)

# %%
puddu_crime = crime_type[715:716]
puddu_crime
# Out:
#        STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 715  PUDUCHERRY    TOTAL  2001      25                 32
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 715                                          1     9               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 715           9                       4  ...     31                 635
#
#      DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 715             1                                                 35
#
#      INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 715                          27                                    3
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 715                                            0                          166
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES
# 715              2324              4068
#
# [1 rows x 33 columns]

# %%
puddu_crime = puddu_crime['TOTAL IPC CRIMES']
puddu_crime
# Out:
# 715    4068
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
# extracting literacy data for Puducherry from above table(literacy1)

# %%
puddu_literacy = literacy1[35:36]
puddu_literacy
# Out:
#            Category Country/ States/ Union Territories Name  \
# 35  Union Territory                              Puducherry
#
#     Literacy Rate (Persons) - Total - 2001  \
# 35                                    81.2
#
#     Literacy Rate (Persons) - Total - 2011  \
# 35                                    85.8
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 35                                    74.0
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 35                                    80.1
#
#     Literacy Rate (Persons) - Urban - 2001  \
# 35                                    84.8
#
#     Literacy Rate (Persons) - Urban - 2011
# 35                                    88.5

# %%
puddu_literacy = puddu_literacy['Literacy Rate (Persons) - Total - 2001']
puddu_literacy
# Out:
# 35    81.2
# Name: Literacy Rate (Persons) - Total - 2001, dtype: float64

# %%
plt.scatter(puddu_crime,puddu_literacy)

plt.xlabel('crime')
plt.ylabel('literacy')

plt.show()
